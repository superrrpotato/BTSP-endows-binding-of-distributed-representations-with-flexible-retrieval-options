# %%
# ============================================================
# EMNIST 3-letter detection
# Clean Center-Heatmap version
#
# Settings kept from previous discussion:
# - EMNIST letters split
# - 64 x 64 canvas
# - exactly 3 handwritten letters per image
# - each letter is 28 x 28
# - integer center placement
# - no x/y movement in augmentation
# - small rotation around +/-10 degrees
# - slight scale up/down
# - no flipping
# - cached synthetic training set, 240k samples
# - no DataLoader multiprocessing in notebook
# - train/test curves and checkpoints
# ============================================================

import os
import random
from itertools import permutations

import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

from torchvision.datasets import EMNIST
from torchvision.transforms import ToTensor
from torchvision.transforms import functional as TF
from torchvision.transforms import InterpolationMode

try:
    from tqdm.notebook import tqdm
except Exception:
    from tqdm import tqdm


torch.backends.cudnn.benchmark = True

try:
    torch.set_float32_matmul_precision("high")
except Exception:
    pass


# ============================================================
# Basic setup
# ============================================================

def seed_all(seed: int = 0):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)


def fix_emnist_orientation(img: torch.Tensor) -> torch.Tensor:
    img = torch.transpose(img, 1, 2)
    return img


def label_to_str(v, class_names=None):
    v = int(v)

    if class_names is None:
        return str(v)

    if 0 <= v < len(class_names):
        return str(class_names[v])

    return str(v)


# ============================================================
# Geometry helpers
# ============================================================

def rect_intersection_area_xyxy(a, b):
    ax1, ay1, ax2, ay2 = a
    bx1, by1, bx2, by2 = b

    ix1 = max(ax1, bx1)
    iy1 = max(ay1, by1)
    ix2 = min(ax2, bx2)
    iy2 = min(ay2, by2)

    iw = max(0, ix2 - ix1)
    ih = max(0, iy2 - iy1)

    return iw * ih


def rect_center_distance_sq(a, b):
    ax1, ay1, ax2, ay2 = a
    bx1, by1, bx2, by2 = b

    acx = 0.5 * (ax1 + ax2)
    acy = 0.5 * (ay1 + ay2)

    bcx = 0.5 * (bx1 + bx2)
    bcy = 0.5 * (by1 + by2)

    return (acx - bcx) ** 2 + (acy - bcy) ** 2


def box_iou_xyxy(a, b, eps=1e-6):
    ax1, ay1, ax2, ay2 = a.unbind(-1)
    bx1, by1, bx2, by2 = b.unbind(-1)

    ix1 = torch.maximum(ax1, bx1)
    iy1 = torch.maximum(ay1, by1)
    ix2 = torch.minimum(ax2, bx2)
    iy2 = torch.minimum(ay2, by2)

    iw = (ix2 - ix1).clamp(min=0.0)
    ih = (iy2 - iy1).clamp(min=0.0)
    inter = iw * ih

    area_a = (ax2 - ax1).clamp(min=0.0) * (ay2 - ay1).clamp(min=0.0)
    area_b = (bx2 - bx1).clamp(min=0.0) * (by2 - by1).clamp(min=0.0)

    union = area_a + area_b - inter + eps

    return inter / union


def best_match_perm_l1(pred_boxes, gt_boxes):
    k = pred_boxes.shape[0]
    all_perms = list(permutations(range(k)))

    best_p = None
    best_cost = None

    for p in all_perms:
        cost = 0.0

        for i in range(k):
            cost += (pred_boxes[i] - gt_boxes[p[i]]).abs().mean().item()

        if best_cost is None or cost < best_cost:
            best_cost = cost
            best_p = p

    return best_p


_PERM_CACHE = {}

def get_perm_tensor(k, device):
    key = (k, str(device))

    if key not in _PERM_CACHE:
        perms = list(permutations(range(k)))
        _PERM_CACHE[key] = torch.tensor(perms, dtype=torch.long, device=device)

    return _PERM_CACHE[key]


def match_by_l1_batch(pred_boxes, gt_boxes, gt_labels):
    B, K, _ = pred_boxes.shape
    device = pred_boxes.device

    perms = get_perm_tensor(K, device)

    all_costs = []

    for p in perms:
        gt_perm = gt_boxes[:, p, :]
        cost = (pred_boxes - gt_perm).abs().mean(dim=(1, 2))
        all_costs.append(cost)

    all_costs = torch.stack(all_costs, dim=1)
    best_idx = all_costs.argmin(dim=1)

    selected_perm = perms[best_idx]

    box_index = selected_perm[:, :, None].expand(B, K, 4)
    matched_boxes = gt_boxes.gather(dim=1, index=box_index)

    matched_labels = gt_labels.gather(dim=1, index=selected_perm)

    return matched_boxes, matched_labels


# ============================================================
# Safe augmentation
# ============================================================

def augment_emnist_letter(img, rng):
    # No x/y translation.
    # No flipping.
    # No 90-degree rotation.
    # Small rotation and slight scaling only.

    if rng.random() < 0.80:
        angle = rng.uniform(-10.0, 10.0)
        scale = rng.uniform(0.92, 1.08)

        img = TF.affine(
            img,
            angle=angle,
            translate=(0, 0),
            scale=scale,
            shear=(0.0, 0.0),
            interpolation=InterpolationMode.BILINEAR,
            fill=0.0,
        )

    if rng.random() < 0.20:
        factor = rng.uniform(0.90, 1.10)
        img = (img * factor).clamp(0.0, 1.0)

    if rng.random() < 0.15:
        noise_std = rng.uniform(0.005, 0.02)
        img = (img + torch.randn_like(img) * noise_std).clamp(0.0, 1.0)

    return img.clamp(0.0, 1.0)


# ============================================================
# Fast integer-center rendering
# ============================================================

def center_is_valid(cx, cy, placed_centers, object_size=28, min_separation=2):
    gap = object_size + min_separation

    for pcx, pcy in placed_centers:
        too_close_x = abs(cx - pcx) < gap
        too_close_y = abs(cy - pcy) < gap

        if too_close_x and too_close_y:
            return False

    return True


def sample_center_fast(
    rng,
    canvas_size,
    object_size=28,
    placed_centers=None,
    min_separation=2,
    allow_overlap=False,
    tries=80,
):
    if placed_centers is None:
        placed_centers = []

    half = object_size // 2

    min_c = half
    max_c = canvas_size - half

    for _ in range(tries):
        cx = rng.randint(min_c, max_c)
        cy = rng.randint(min_c, max_c)

        if allow_overlap:
            return cx, cy

        if center_is_valid(
            cx,
            cy,
            placed_centers,
            object_size=object_size,
            min_separation=min_separation,
        ):
            return cx, cy

    best_center = None
    best_score = None
    gap = object_size + min_separation

    for cx in range(min_c, max_c + 1):
        for cy in range(min_c, max_c + 1):
            score = 0.0

            for pcx, pcy in placed_centers:
                vx = max(0, gap - abs(cx - pcx))
                vy = max(0, gap - abs(cy - pcy))
                score += vx * vy

            if best_score is None or score < best_score:
                best_score = score
                best_center = (cx, cy)

            if score == 0.0:
                return cx, cy

    return best_center


def render_boxes_on_canvas(
    canvas_size,
    char_imgs,
    char_labels,
    rng,
    allow_overlap=False,
    placement_tries=80,
    min_separation=2,
):
    H = W = int(canvas_size)
    object_size = 28
    half = object_size // 2

    canvas = torch.zeros(1, H, W, dtype=torch.float32)

    boxes_norm = []
    labels = []
    placed_centers = []

    for img, lab in zip(char_imgs, char_labels):
        h, w = img.shape[-2], img.shape[-1]

        if h != 28 or w != 28:
            raise ValueError(f"Expected 28x28 EMNIST character, got {h}x{w}")

        cx, cy = sample_center_fast(
            rng=rng,
            canvas_size=canvas_size,
            object_size=object_size,
            placed_centers=placed_centers,
            min_separation=min_separation,
            allow_overlap=allow_overlap,
            tries=placement_tries,
        )

        placed_centers.append((cx, cy))

        x = cx - half
        y = cy - half

        patch = canvas[:, y:y + h, x:x + w]
        canvas[:, y:y + h, x:x + w] = torch.maximum(patch, img)

        x1 = x / W
        y1 = y / H
        x2 = (x + w) / W
        y2 = (y + h) / H

        boxes_norm.append(torch.tensor([x1, y1, x2, y2], dtype=torch.float32))
        labels.append(int(lab))

    boxes = torch.stack(boxes_norm, dim=0)
    labels = torch.tensor(labels, dtype=torch.long)

    return canvas, boxes, labels


# ============================================================
# Dataset
# ============================================================

class ThreeCharEMNIST(Dataset):
    def __init__(
        self,
        root="./data",
        train=True,
        split="letters",
        canvas_size=64,
        chars_per_image=3,
        length=5000,
        seed=1,
        allow_overlap=False,
        placement_tries=80,
        min_separation=2,
        augment=False,
    ):
        self.split = split

        self.ds = EMNIST(
            root=root,
            split=split,
            train=train,
            download=True,
            transform=ToTensor(),
        )

        self.canvas_size = int(canvas_size)
        self.k = int(chars_per_image)
        self.length = int(length)
        self.base_seed = int(seed)
        self.train = bool(train)
        self.allow_overlap = bool(allow_overlap)
        self.placement_tries = int(placement_tries)
        self.min_separation = int(min_separation)
        self.augment = bool(augment)

        self.num_classes = self._infer_num_classes(split)
        self.class_names = self._build_class_names(split)

    @staticmethod
    def _infer_num_classes(split):
        if split in {"digits", "mnist"}:
            return 10

        if split == "letters":
            return 26

        if split in {"balanced", "bymerge"}:
            return 47

        if split == "byclass":
            return 62

        raise ValueError(f"Unknown EMNIST split: {split}")

    @staticmethod
    def _build_class_names(split):
        if split in {"digits", "mnist"}:
            return [str(i) for i in range(10)]

        if split == "letters":
            return [chr(ord("a") + i) for i in range(26)]

        n = ThreeCharEMNIST._infer_num_classes(split)
        return [str(i) for i in range(n)]

    def _normalize_label(self, lab):
        lab = int(lab)

        if self.split == "letters":
            return lab - 1

        return lab

    def __len__(self):
        return self.length

    def __getitem__(self, idx):
        rng = random.Random(self.base_seed + idx + (0 if self.train else 10_000_000))

        char_imgs = []
        char_labels = []

        n = len(self.ds)

        for _ in range(self.k):
            j = rng.randint(0, n - 1)

            img, lab = self.ds[j]
            img = fix_emnist_orientation(img)

            if self.train and self.augment:
                img = augment_emnist_letter(img, rng)

            lab = self._normalize_label(lab)

            char_imgs.append(img)
            char_labels.append(lab)

        canvas, boxes, labels = render_boxes_on_canvas(
            canvas_size=self.canvas_size,
            char_imgs=char_imgs,
            char_labels=char_labels,
            rng=rng,
            allow_overlap=self.allow_overlap,
            placement_tries=self.placement_tries,
            min_separation=self.min_separation,
        )

        return canvas, boxes, labels


class CachedThreeCharDataset(Dataset):
    def __init__(self, cache_path, source_ds=None, rebuild=False):
        self.cache_path = cache_path

        if os.path.exists(cache_path) and not rebuild:
            obj = torch.load(cache_path, map_location="cpu")

            self.images = obj["images"]
            self.boxes = obj["boxes"]
            self.labels = obj["labels"]
            self.num_classes = obj["num_classes"]
            self.class_names = obj["class_names"]
            self.k = obj["k"]
            self.canvas_size = obj["canvas_size"]

            return

        if source_ds is None:
            raise ValueError("source_ds is required when building a new cache")

        n = len(source_ds)
        canvas_size = source_ds.canvas_size
        k = source_ds.k

        images = torch.empty(n, 1, canvas_size, canvas_size, dtype=torch.uint8)
        boxes = torch.empty(n, k, 4, dtype=torch.float32)
        labels = torch.empty(n, k, dtype=torch.long)

        for i in tqdm(range(n), desc=f"building cache {cache_path}"):
            x, b, y = source_ds[i]

            images[i] = (x * 255).clamp(0, 255).byte()
            boxes[i] = b
            labels[i] = y

        obj = {
            "images": images,
            "boxes": boxes,
            "labels": labels,
            "num_classes": source_ds.num_classes,
            "class_names": source_ds.class_names,
            "k": source_ds.k,
            "canvas_size": source_ds.canvas_size,
        }

        os.makedirs(os.path.dirname(cache_path), exist_ok=True)
        torch.save(obj, cache_path)

        self.images = images
        self.boxes = boxes
        self.labels = labels
        self.num_classes = source_ds.num_classes
        self.class_names = source_ds.class_names
        self.k = source_ds.k
        self.canvas_size = source_ds.canvas_size

    def __len__(self):
        return self.images.shape[0]

    def __getitem__(self, idx):
        x = self.images[idx].float() / 255.0
        b = self.boxes[idx]
        y = self.labels[idx]

        return x, b, y


# ============================================================
# Center-heatmap model
# ============================================================

class ConvBlock(nn.Module):
    def __init__(self, in_ch, out_ch):
        super().__init__()

        self.net = nn.Sequential(
            nn.Conv2d(in_ch, out_ch, 3, padding=1, bias=False),
            nn.BatchNorm2d(out_ch),
            nn.ReLU(inplace=True),
        )

    def forward(self, x):
        return self.net(x)


class ResidualBlock(nn.Module):
    def __init__(self, ch, dilation=1):
        super().__init__()

        self.conv1 = nn.Conv2d(
            ch,
            ch,
            3,
            padding=dilation,
            dilation=dilation,
            bias=False,
        )

        self.bn1 = nn.BatchNorm2d(ch)

        self.conv2 = nn.Conv2d(
            ch,
            ch,
            3,
            padding=dilation,
            dilation=dilation,
            bias=False,
        )

        self.bn2 = nn.BatchNorm2d(ch)

    def forward(self, x):
        z = self.conv1(x)
        z = self.bn1(z)
        z = F.relu(z, inplace=True)

        z = self.conv2(z)
        z = self.bn2(z)

        return F.relu(x + z, inplace=True)


class CenterHeatmapDetector(nn.Module):
    def __init__(
        self,
        num_classes=26,
        base_ch=64,
        canvas_size=64,
        object_size=28,
    ):
        super().__init__()

        self.num_classes = int(num_classes)
        self.canvas_size = int(canvas_size)
        self.object_size = int(object_size)

        self.stem = nn.Sequential(
            ConvBlock(1, base_ch),
            ConvBlock(base_ch, base_ch),
        )

        self.body = nn.Sequential(
            ResidualBlock(base_ch, dilation=1),
            ResidualBlock(base_ch, dilation=2),
            ResidualBlock(base_ch, dilation=3),
            ResidualBlock(base_ch, dilation=4),
            ResidualBlock(base_ch, dilation=1),
        )

        self.head = nn.Sequential(
            ConvBlock(base_ch, base_ch),
            nn.Conv2d(base_ch, self.num_classes, 1),
        )

        self._init_heatmap_bias()

    def _init_heatmap_bias(self):
        final_conv = self.head[-1]
        nn.init.constant_(final_conv.bias, -4.0)

    def forward(self, x):
        z = self.stem(x)
        z = self.body(z)
        logits = self.head(z)

        return logits


# ============================================================
# Heatmap targets, loss, decoding
# ============================================================

def make_valid_center_mask(
    canvas_size=64,
    object_size=28,
    device="cpu",
):
    half = object_size // 2

    valid = torch.zeros(
        1,
        1,
        canvas_size,
        canvas_size,
        dtype=torch.float32,
        device=device,
    )

    valid[:, :, half:canvas_size - half + 1, half:canvas_size - half + 1] = 1.0

    return valid


def boxes_to_integer_centers_px(gt_boxes, canvas_size=64):
    cx = ((gt_boxes[..., 0] + gt_boxes[..., 2]) * 0.5 * canvas_size).round().long()
    cy = ((gt_boxes[..., 1] + gt_boxes[..., 3]) * 0.5 * canvas_size).round().long()

    cx = cx.clamp(0, canvas_size - 1)
    cy = cy.clamp(0, canvas_size - 1)

    return cx, cy


def build_center_heatmap_targets(
    gt_boxes,
    gt_labels,
    num_classes=26,
    canvas_size=64,
    radius=1,
    sigma=1.0,
):
    B, K, _ = gt_boxes.shape
    device = gt_boxes.device

    targets = torch.zeros(
        B,
        num_classes,
        canvas_size,
        canvas_size,
        dtype=torch.float32,
        device=device,
    )

    gt_cx, gt_cy = boxes_to_integer_centers_px(
        gt_boxes,
        canvas_size=canvas_size,
    )

    b_idx = torch.arange(B, device=device)[:, None].expand(B, K)

    flat_idx = (
        ((b_idx * num_classes + gt_labels) * canvas_size + gt_cy) * canvas_size + gt_cx
    )

    targets.view(-1)[flat_idx.reshape(-1)] = 1.0

    if radius > 0:
        size = 2 * radius + 1

        coords = torch.arange(
            -radius,
            radius + 1,
            device=device,
            dtype=torch.float32,
        )

        yy, xx = torch.meshgrid(coords, coords, indexing="ij")

        kernel = torch.exp(
            -((xx ** 2 + yy ** 2) / (2.0 * sigma ** 2))
        )

        kernel = kernel / kernel.max()
        kernel = kernel.view(1, 1, size, size)
        kernel = kernel.expand(num_classes, 1, size, size)

        targets = F.conv2d(
            targets,
            kernel,
            padding=radius,
            groups=num_classes,
        )

        targets = targets.clamp(0.0, 1.0)

    return targets


def heatmap_focal_loss(
    logits,
    targets,
    valid_mask=None,
    alpha=2.0,
    beta=4.0,
):
    pred = torch.sigmoid(logits).clamp(1e-4, 1.0 - 1e-4)

    pos = targets.eq(1.0).float()
    neg = targets.lt(1.0).float()

    neg_weights = (1.0 - targets).pow(beta)

    if valid_mask is not None:
        pos = pos * valid_mask
        neg = neg * valid_mask
        neg_weights = neg_weights * valid_mask

    pos_loss = -torch.log(pred) * (1.0 - pred).pow(alpha) * pos
    neg_loss = -torch.log(1.0 - pred) * pred.pow(alpha) * neg_weights * neg

    num_pos = pos.sum().clamp(min=1.0)

    loss = (pos_loss.sum() + neg_loss.sum()) / num_pos

    return loss


def centers_to_boxes_from_int(
    cx,
    cy,
    canvas_size=64,
    object_size=28,
):
    half = object_size // 2

    x1 = (cx.float() - half) / float(canvas_size)
    y1 = (cy.float() - half) / float(canvas_size)
    x2 = (cx.float() + half) / float(canvas_size)
    y2 = (cy.float() + half) / float(canvas_size)

    boxes = torch.stack([x1, y1, x2, y2], dim=-1)

    return boxes.clamp(0.0, 1.0)


def nms_heatmap(prob, kernel=3):
    pad = kernel // 2

    pooled = F.max_pool2d(
        prob,
        kernel_size=kernel,
        stride=1,
        padding=pad,
    )

    keep = pooled.eq(prob)

    return prob * keep.float()


@torch.no_grad()
def decode_heatmap_topk(
    logits,
    k=3,
    canvas_size=64,
    object_size=28,
):
    B, C, H, W = logits.shape
    device = logits.device

    prob = torch.sigmoid(logits)

    valid_mask = make_valid_center_mask(
        canvas_size=canvas_size,
        object_size=object_size,
        device=device,
    )

    prob = prob * valid_mask
    prob = nms_heatmap(prob, kernel=3)

    flat = prob.reshape(B, -1)

    scores, inds = torch.topk(flat, k=k, dim=1)

    class_ids = inds // (H * W)
    rem = inds % (H * W)

    cy = rem // W
    cx = rem % W

    boxes = centers_to_boxes_from_int(
        cx=cx,
        cy=cy,
        canvas_size=canvas_size,
        object_size=object_size,
    )

    return boxes, class_ids.long(), scores


# ============================================================
# Evaluation
# ============================================================

@torch.no_grad()
def evaluate_heatmap_detector(
    model,
    loader,
    device,
    num_classes=26,
    canvas_size=64,
    object_size=28,
    k=3,
    iou_threshold=0.5,
    target_radius=1,
    max_batches=None,
):
    model.eval()

    valid_mask = make_valid_center_mask(
        canvas_size=canvas_size,
        object_size=object_size,
        device=device,
    )

    total_loss = 0.0
    num_batches = 0

    total_images = 0
    total_objects = 0

    correct_cls = 0
    total_iou = 0.0
    total_box_l1 = 0.0
    correct_det = 0
    exact_set_correct = 0

    for batch_idx, (x, gt_boxes, gt_labels) in enumerate(loader):
        x = x.to(device, non_blocking=True)
        gt_boxes = gt_boxes.to(device, non_blocking=True)
        gt_labels = gt_labels.to(device, non_blocking=True)

        logits = model(x)

        targets = build_center_heatmap_targets(
            gt_boxes=gt_boxes,
            gt_labels=gt_labels,
            num_classes=num_classes,
            canvas_size=canvas_size,
            radius=target_radius,
            sigma=1.0,
        )

        loss = heatmap_focal_loss(
            logits=logits,
            targets=targets,
            valid_mask=valid_mask,
        )

        total_loss += float(loss.item())
        num_batches += 1

        pred_boxes, pred_labels, pred_scores = decode_heatmap_topk(
            logits=logits,
            k=k,
            canvas_size=canvas_size,
            object_size=object_size,
        )

        matched_gt_boxes, matched_gt_labels = match_by_l1_batch(
            pred_boxes=pred_boxes,
            gt_boxes=gt_boxes,
            gt_labels=gt_labels,
        )

        B, K, _ = pred_boxes.shape

        ious = box_iou_xyxy(
            pred_boxes.reshape(-1, 4),
            matched_gt_boxes.reshape(-1, 4),
        ).reshape(B, K)

        cls_ok = pred_labels == matched_gt_labels
        det_ok = cls_ok & (ious >= iou_threshold)

        correct_cls += int(cls_ok.sum().item())
        total_iou += float(ious.sum().item())

        total_box_l1 += float(
            (pred_boxes - matched_gt_boxes)
            .abs()
            .mean(dim=-1)
            .sum()
            .item()
        )

        correct_det += int(det_ok.sum().item())
        exact_set_correct += int(det_ok.all(dim=1).sum().item())

        total_objects += B * K
        total_images += B

        if max_batches is not None and (batch_idx + 1) >= max_batches:
            break

    metrics = {
        "loss": total_loss / max(num_batches, 1),
        "cls_acc": correct_cls / max(total_objects, 1),
        "mean_iou": total_iou / max(total_objects, 1),
        "mean_box_l1": total_box_l1 / max(total_objects, 1),
        "det_acc": correct_det / max(total_objects, 1),
        "exact_set_acc": exact_set_correct / max(total_images, 1),
        "num_images": total_images,
        "num_objects": total_objects,
    }

    return metrics


# ============================================================
# Visualization
# ============================================================

@torch.no_grad()
def show_heatmap_predictions(
    model,
    loader,
    device,
    class_names=None,
    canvas_size=64,
    object_size=28,
    k=3,
    num_images=9,
    ncols=3,
    title=None,
):
    model.eval()

    x, gt_boxes, gt_labels = next(iter(loader))

    x = x.to(device)[:num_images]
    gt_boxes = gt_boxes.to(device)[:num_images]
    gt_labels = gt_labels.to(device)[:num_images]

    logits = model(x)

    pred_boxes, pred_labels, pred_scores = decode_heatmap_topk(
        logits=logits,
        k=k,
        canvas_size=canvas_size,
        object_size=object_size,
    )

    imgs = x.detach().cpu().squeeze(1)
    pb = pred_boxes.detach().cpu()
    pl = pred_labels.detach().cpu()
    ps = pred_scores.detach().cpu()
    gb = gt_boxes.detach().cpu()
    gl = gt_labels.detach().cpu()

    matched_gb = []
    matched_gl = []
    matched_iou = []

    for i in range(num_images):
        p = best_match_perm_l1(pb[i], gb[i])
        p = torch.tensor(p, dtype=torch.long)

        mgb = gb[i][p]
        mgl = gl[i][p]
        iou = box_iou_xyxy(pb[i], mgb)

        matched_gb.append(mgb)
        matched_gl.append(mgl)
        matched_iou.append(iou)

    matched_gb = torch.stack(matched_gb)
    matched_gl = torch.stack(matched_gl)
    matched_iou = torch.stack(matched_iou)

    nrows = (num_images + ncols - 1) // ncols

    fig, axes = plt.subplots(
        nrows,
        ncols,
        figsize=(3.2 * ncols, 3.2 * nrows),
    )

    axes = axes.flatten() if hasattr(axes, "flatten") else [axes]

    if title is not None:
        fig.suptitle(title, fontsize=14)

    for i in range(num_images):
        ax = axes[i]
        ax.imshow(imgs[i], cmap="gray", vmin=0, vmax=1)
        ax.axis("off")

        for j in range(k):
            x1, y1, x2, y2 = matched_gb[i, j].tolist()

            x1 *= canvas_size
            x2 *= canvas_size
            y1 *= canvas_size
            y2 *= canvas_size

            rect = plt.Rectangle(
                (x1, y1),
                x2 - x1,
                y2 - y1,
                fill=False,
                linewidth=1.0,
                color="white",
            )

            ax.add_patch(rect)

            ax.text(
                x1,
                y1,
                f"gt {label_to_str(matched_gl[i, j], class_names)}",
                fontsize=11,
                color="white",
            )

        for j in range(k):
            x1, y1, x2, y2 = pb[i, j].tolist()

            x1 *= canvas_size
            x2 *= canvas_size
            y1 *= canvas_size
            y2 *= canvas_size

            rect = plt.Rectangle(
                (x1, y1),
                x2 - x1,
                y2 - y1,
                fill=False,
                linewidth=1.0,
                color="red",
            )

            ax.add_patch(rect)

            ax.text(
                x1,
                y2,
                f"p {label_to_str(pl[i, j], class_names)} "
                f"{float(ps[i, j]):.2f} "
                f"iou {float(matched_iou[i, j]):.2f}",
                fontsize=11,
                color="red",
            )

    for j in range(num_images, len(axes)):
        axes[j].axis("off")

    plt.tight_layout()
    plt.show()


# ============================================================
# Checkpoint and plotting helpers
# ============================================================

def save_checkpoint_heatmap(
    path,
    model,
    emnist_split,
    num_classes,
    class_names,
    k,
    canvas_size,
    object_size,
    extra=None,
):
    payload = {
        "model": model.state_dict(),
        "model_state_dict": model.state_dict(),
        "architecture": "center_heatmap_detector",
        "emnist_split": emnist_split,
        "num_classes": num_classes,
        "class_names": class_names,
        "k": k,
        "canvas_size": canvas_size,
        "object_size": object_size,
    }

    if extra is not None:
        payload.update(extra)

    torch.save(payload, path)


def plot_heatmap_training_curves(history):
    plt.figure(figsize=(4, 3))
    plt.plot(
        history["train_log_steps"],
        history["train_batch_loss"],
        label="train batch loss",
    )
    plt.xlabel("global step")
    plt.ylabel("loss")
    plt.title("Training loss")
    plt.legend()
    plt.tight_layout()
    plt.show()

    plt.figure(figsize=(4, 3))
    plt.plot(
        history["eval_steps"],
        history["train_eval_loss"],
        label="train eval loss",
    )
    plt.plot(
        history["eval_steps"],
        history["val_loss"],
        label="test loss",
    )
    plt.xlabel("global step")
    plt.ylabel("loss")
    plt.title("Train vs test loss")
    plt.legend()
    plt.tight_layout()
    plt.show()

    plt.figure(figsize=(4, 3))
    plt.plot(
        history["eval_steps"],
        history["train_cls_acc"],
        label="train cls acc",
    )
    plt.plot(
        history["eval_steps"],
        history["val_cls_acc"],
        label="test cls acc",
    )
    plt.xlabel("global step")
    plt.ylabel("accuracy")
    plt.title("Classification accuracy")
    plt.legend()
    plt.tight_layout()
    plt.show()

    plt.figure(figsize=(4, 3))
    plt.plot(
        history["eval_steps"],
        history["train_det_acc"],
        label="train det acc",
    )
    plt.plot(
        history["eval_steps"],
        history["val_det_acc"],
        label="test det acc",
    )
    plt.xlabel("global step")
    plt.ylabel("accuracy")
    plt.title("Detection accuracy")
    plt.legend()
    plt.tight_layout()
    plt.show()

    plt.figure(figsize=(4, 3))
    plt.plot(
        history["eval_steps"],
        history["train_exact_set_acc"],
        label="train exact",
    )
    plt.plot(
        history["eval_steps"],
        history["val_exact_set_acc"],
        label="test exact",
    )
    plt.xlabel("global step")
    plt.ylabel("accuracy")
    plt.title("Exact set accuracy")
    plt.legend()
    plt.tight_layout()
    plt.show()

    plt.figure(figsize=(4, 3))
    plt.plot(
        history["eval_steps"],
        history["train_mean_iou"],
        label="train IoU",
    )
    plt.plot(
        history["eval_steps"],
        history["val_mean_iou"],
        label="test IoU",
    )
    plt.xlabel("global step")
    plt.ylabel("IoU")
    plt.title("Mean IoU")
    plt.legend()
    plt.tight_layout()
    plt.show()


# ============================================================
# Main training function
# ============================================================

rebuild_cache=False,

seed_all(0)

device = "cuda" if torch.cuda.is_available() else "cpu"
print("device", device)

canvas_size = 64
object_size = 28
k = 3

train_length = 240000
train_eval_length = 5000
val_length = 5000

batch_size = 512

viz_every = 3000
eval_every = 3000
log_every = 100
epochs = 80

target_radius = 1
emnist_split = "letters"

raw_train_ds = ThreeCharEMNIST(
    root="./data",
    train=True,
    split=emnist_split,
    canvas_size=canvas_size,
    chars_per_image=k,
    length=train_length,
    seed=0,
    allow_overlap=False,
    placement_tries=80,
    min_separation=2,
    augment=True,
)

raw_train_eval_ds = ThreeCharEMNIST(
    root="./data",
    train=True,
    split=emnist_split,
    canvas_size=canvas_size,
    chars_per_image=k,
    length=train_eval_length,
    seed=123,
    allow_overlap=False,
    placement_tries=80,
    min_separation=2,
    augment=False,
)

raw_val_ds = ThreeCharEMNIST(
    root="./data",
    train=False,
    split=emnist_split,
    canvas_size=canvas_size,
    chars_per_image=k,
    length=val_length,
    seed=1,
    allow_overlap=False,
    placement_tries=80,
    min_separation=2,
    augment=False,
)

train_ds = CachedThreeCharDataset(
    cache_path="./runs/cache_train_aug_240000_heatmap.pt",
    source_ds=raw_train_ds,
    rebuild=rebuild_cache,
)

train_eval_ds = CachedThreeCharDataset(
    cache_path="./runs/cache_train_eval_5000_heatmap.pt",
    source_ds=raw_train_eval_ds,
    rebuild=rebuild_cache,
)

val_ds = CachedThreeCharDataset(
    cache_path="./runs/cache_val_5000_heatmap.pt",
    source_ds=raw_val_ds,
    rebuild=rebuild_cache,
)

train_loader = DataLoader(
    train_ds,
    batch_size=batch_size,
    shuffle=True,
    num_workers=0,
    pin_memory=True,
)

train_eval_loader = DataLoader(
    train_eval_ds,
    batch_size=batch_size,
    shuffle=False,
    num_workers=0,
    pin_memory=True,
)

val_loader = DataLoader(
    val_ds,
    batch_size=batch_size,
    shuffle=False,
    num_workers=0,
    pin_memory=True,
)

num_classes = train_ds.num_classes
class_names = train_ds.class_names

print("architecture: CenterHeatmapDetector")
print("EMNIST split", emnist_split)
print("num_classes", num_classes)
print("canvas_size", canvas_size)
print("object_size", object_size)
print("train_length", train_length)
print("integer center range", object_size // 2, "to", canvas_size - object_size // 2)

model = CenterHeatmapDetector(
    num_classes=num_classes,
    base_ch=64,
    canvas_size=canvas_size,
    object_size=object_size,
).to(device)

opt = torch.optim.AdamW(
    model.parameters(),
    lr=2e-3,
    weight_decay=1e-4,
)

scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(
    opt,
    T_max=epochs,
    eta_min=1e-5,
)

valid_mask = make_valid_center_mask(
    canvas_size=canvas_size,
    object_size=object_size,
    device=device,
)

os.makedirs("./runs", exist_ok=True)

global_step = 0
best_exact_set_acc = -1.0

running_loss = torch.zeros((), device=device)
running_count = 0

history = {
    "train_log_steps": [],
    "train_batch_loss": [],

    "eval_steps": [],

    "train_eval_loss": [],
    "train_cls_acc": [],
    "train_mean_iou": [],
    "train_det_acc": [],
    "train_exact_set_acc": [],

    "val_loss": [],
    "val_cls_acc": [],
    "val_mean_iou": [],
    "val_det_acc": [],
    "val_exact_set_acc": [],
}

for ep in tqdm(range(1, epochs + 1)):
    model.train()

    for x, gt_boxes, gt_labels in train_loader:
        x = x.to(device, non_blocking=True)
        gt_boxes = gt_boxes.to(device, non_blocking=True)
        gt_labels = gt_labels.to(device, non_blocking=True)

        logits = model(x)

        targets = build_center_heatmap_targets(
            gt_boxes=gt_boxes,
            gt_labels=gt_labels,
            num_classes=num_classes,
            canvas_size=canvas_size,
            radius=target_radius,
            sigma=1.0,
        )

        loss = heatmap_focal_loss(
            logits=logits,
            targets=targets,
            valid_mask=valid_mask,
        )

        opt.zero_grad(set_to_none=True)
        loss.backward()
        nn.utils.clip_grad_norm_(model.parameters(), 5.0)
        opt.step()

        running_loss += loss.detach()
        running_count += 1

        global_step += 1

        if global_step % log_every == 0:
            avg_loss = (running_loss / running_count).item()

            history["train_log_steps"].append(global_step)
            history["train_batch_loss"].append(avg_loss)

            print(
                f"epoch {ep} step {global_step} "
                f"loss {avg_loss:.4f}"
            )

            running_loss = torch.zeros((), device=device)
            running_count = 0

        if global_step % eval_every == 0:
            train_metrics = evaluate_heatmap_detector(
                model=model,
                loader=train_eval_loader,
                device=device,
                num_classes=num_classes,
                canvas_size=canvas_size,
                object_size=object_size,
                k=k,
                iou_threshold=0.5,
                target_radius=target_radius,
                max_batches=5,
            )

            val_metrics = evaluate_heatmap_detector(
                model=model,
                loader=val_loader,
                device=device,
                num_classes=num_classes,
                canvas_size=canvas_size,
                object_size=object_size,
                k=k,
                iou_threshold=0.5,
                target_radius=target_radius,
                max_batches=5,
            )

            history["eval_steps"].append(global_step)

            history["train_eval_loss"].append(train_metrics["loss"])
            history["train_cls_acc"].append(train_metrics["cls_acc"])
            history["train_mean_iou"].append(train_metrics["mean_iou"])
            history["train_det_acc"].append(train_metrics["det_acc"])
            history["train_exact_set_acc"].append(train_metrics["exact_set_acc"])

            history["val_loss"].append(val_metrics["loss"])
            history["val_cls_acc"].append(val_metrics["cls_acc"])
            history["val_mean_iou"].append(val_metrics["mean_iou"])
            history["val_det_acc"].append(val_metrics["det_acc"])
            history["val_exact_set_acc"].append(val_metrics["exact_set_acc"])

            print(
                f"[train eval] step {global_step} "
                f"loss {train_metrics['loss']:.4f} "
                f"cls {train_metrics['cls_acc']:.4f} "
                f"iou {train_metrics['mean_iou']:.4f} "
                f"det {train_metrics['det_acc']:.4f} "
                f"exact {train_metrics['exact_set_acc']:.4f}"
            )

            print(
                f"[test eval] step {global_step} "
                f"loss {val_metrics['loss']:.4f} "
                f"cls {val_metrics['cls_acc']:.4f} "
                f"iou {val_metrics['mean_iou']:.4f} "
                f"det {val_metrics['det_acc']:.4f} "
                f"exact {val_metrics['exact_set_acc']:.4f}"
            )

            save_checkpoint_heatmap(
                "./runs/model_latest_heatmap.pt",
                model=model,
                emnist_split=emnist_split,
                num_classes=num_classes,
                class_names=class_names,
                k=k,
                canvas_size=canvas_size,
                object_size=object_size,
                extra={
                    "epoch": ep,
                    "global_step": global_step,
                    "train_metrics": train_metrics,
                    "val_metrics": val_metrics,
                    "history": history,
                    "target_radius": target_radius,
                },
            )

            if val_metrics["exact_set_acc"] > best_exact_set_acc:
                best_exact_set_acc = val_metrics["exact_set_acc"]

                save_checkpoint_heatmap(
                    "./runs/best_model_heatmap.pt",
                    model=model,
                    emnist_split=emnist_split,
                    num_classes=num_classes,
                    class_names=class_names,
                    k=k,
                    canvas_size=canvas_size,
                    object_size=object_size,
                    extra={
                        "epoch": ep,
                        "global_step": global_step,
                        "train_metrics": train_metrics,
                        "val_metrics": val_metrics,
                        "best_exact_set_acc": best_exact_set_acc,
                        "history": history,
                        "target_radius": target_radius,
                    },
                )

                print(f"saved new best heatmap model, exact_set_acc {best_exact_set_acc:.4f}")

        if global_step % viz_every == 0:
            show_heatmap_predictions(
                model=model,
                loader=val_loader,
                device=device,
                class_names=class_names,
                canvas_size=canvas_size,
                object_size=object_size,
                k=k,
                num_images=9,
                ncols=3,
                title=f"step {global_step}",
            )

    scheduler.step()

    if ep % 10 == 0:
        save_checkpoint_heatmap(
            f"./runs/model_epoch{ep}_heatmap.pt",
            model=model,
            emnist_split=emnist_split,
            num_classes=num_classes,
            class_names=class_names,
            k=k,
            canvas_size=canvas_size,
            object_size=object_size,
            extra={
                "epoch": ep,
                "global_step": global_step,
                "history": history,
                "target_radius": target_radius,
            },
        )

final_train_metrics = evaluate_heatmap_detector(
    model=model,
    loader=train_eval_loader,
    device=device,
    num_classes=num_classes,
    canvas_size=canvas_size,
    object_size=object_size,
    k=k,
    iou_threshold=0.5,
    target_radius=target_radius,
    max_batches=None,
)

final_val_metrics = evaluate_heatmap_detector(
    model=model,
    loader=val_loader,
    device=device,
    num_classes=num_classes,
    canvas_size=canvas_size,
    object_size=object_size,
    k=k,
    iou_threshold=0.5,
    target_radius=target_radius,
    max_batches=None,
)

save_checkpoint_heatmap(
    "./runs/model_final_heatmap.pt",
    model=model,
    emnist_split=emnist_split,
    num_classes=num_classes,
    class_names=class_names,
    k=k,
    canvas_size=canvas_size,
    object_size=object_size,
    extra={
        "epoch": epochs,
        "global_step": global_step,
        "final_train_metrics": final_train_metrics,
        "final_val_metrics": final_val_metrics,
        "history": history,
        "target_radius": target_radius,
    },
)

print("done")
print("best checkpoint is ./runs/best_model_heatmap.pt")
print("final checkpoint is ./runs/model_final_heatmap.pt")
print("final train metrics", final_train_metrics)
print("final test metrics", final_val_metrics)

plot_heatmap_training_curves(history)
# Out:
# device cuda
# building cache ./runs/cache_train_aug_240000_heatmap.pt:   0%|          | 0/240000 [00:00<?, ?it/s]
# building cache ./runs/cache_train_eval_5000_heatmap.pt:   0%|          | 0/5000 [00:00<?, ?it/s]
# building cache ./runs/cache_val_5000_heatmap.pt:   0%|          | 0/5000 [00:00<?, ?it/s]
# architecture: CenterHeatmapDetector
# EMNIST split letters
# num_classes 26
# canvas_size 64
# object_size 28
# train_length 240000
# integer center range 14 to 50
#   0%|          | 0/80 [00:00<?, ?it/s]
# epoch 1 step 100 loss 1.1781
# epoch 1 step 200 loss 0.3644
# epoch 1 step 300 loss 0.2418
# epoch 1 step 400 loss 0.2016
# epoch 2 step 500 loss 0.1787
# epoch 2 step 600 loss 0.1628
# epoch 2 step 700 loss 0.1512
# epoch 2 step 800 loss 0.1426
# epoch 2 step 900 loss 0.1375
# epoch 3 step 1000 loss 0.1264
# epoch 3 step 1100 loss 0.1225
# epoch 3 step 1200 loss 0.1178
# epoch 3 step 1300 loss 0.1158
# epoch 3 step 1400 loss 0.1117
# epoch 4 step 1500 loss 0.1049
# epoch 4 step 1600 loss 0.1034
# epoch 4 step 1700 loss 0.1022
# epoch 4 step 1800 loss 0.0983
# epoch 5 step 1900 loss 0.0987
# epoch 5 step 2000 loss 0.0889
# epoch 5 step 2100 loss 0.0888
# epoch 5 step 2200 loss 0.0903
# epoch 5 step 2300 loss 0.0890
# epoch 6 step 2400 loss 0.0836
# epoch 6 step 2500 loss 0.0798
# epoch 6 step 2600 loss 0.0818
# epoch 6 step 2700 loss 0.0808
# epoch 6 step 2800 loss 0.0810
# epoch 7 step 2900 loss 0.0733
# epoch 7 step 3000 loss 0.0753
# [train eval] step 3000 loss 0.0656 cls 0.9629 iou 0.9941 det 0.9628 exact 0.8945
# [test eval] step 3000 loss 0.1209 cls 0.9449 iou 0.9929 det 0.9448 exact 0.8449
# saved new best heatmap model, exact_set_acc 0.8449
# epoch 7 step 3100 loss 18.5811
# epoch 7 step 3200 loss 1.2863
# epoch 8 step 3300 loss 1.1547
# epoch 8 step 3400 loss 0.7358
# epoch 8 step 3500 loss 0.2966
# epoch 8 step 3600 loss 0.2267
# epoch 8 step 3700 loss 0.1982
# epoch 9 step 3800 loss 0.1754
# epoch 9 step 3900 loss 0.1620
# epoch 9 step 4000 loss 0.1534
# epoch 9 step 4100 loss 0.1454
# epoch 9 step 4200 loss 0.1401
# epoch 10 step 4300 loss 0.1317
# epoch 10 step 4400 loss 0.1257
# epoch 10 step 4500 loss 0.1263
# epoch 10 step 4600 loss 0.1199
# epoch 11 step 4700 loss 0.1160
# epoch 11 step 4800 loss 0.1090
# epoch 11 step 4900 loss 0.1074
# epoch 11 step 5000 loss 0.1086
# epoch 11 step 5100 loss 0.1057
# epoch 12 step 5200 loss 0.1003
# epoch 12 step 5300 loss 0.0983
# epoch 12 step 5400 loss 0.0981
# epoch 12 step 5500 loss 0.0970
# epoch 12 step 5600 loss 0.0936
# epoch 13 step 5700 loss 0.0887
# epoch 13 step 5800 loss 0.0882
# epoch 13 step 5900 loss 0.0873
# epoch 13 step 6000 loss 0.0860
# [train eval] step 6000 loss 0.0753 cls 0.9600 iou 0.9939 det 0.9599 exact 0.8859
# [test eval] step 6000 loss 0.1146 cls 0.9449 iou 0.9932 det 0.9448 exact 0.8453
# saved new best heatmap model, exact_set_acc 0.8453
# epoch 14 step 6100 loss 0.5482
# epoch 14 step 6200 loss 0.1294
# epoch 14 step 6300 loss 0.0984
# epoch 14 step 6400 loss 0.0900
# epoch 14 step 6500 loss 0.0863
# epoch 15 step 6600 loss 0.0809
# epoch 15 step 6700 loss 0.0765
# epoch 15 step 6800 loss 0.0770
# epoch 15 step 6900 loss 0.0764
# epoch 15 step 7000 loss 0.0744
# epoch 16 step 7100 loss 0.0714
# epoch 16 step 7200 loss 0.0693
# epoch 16 step 7300 loss 0.0713
# epoch 16 step 7400 loss 0.0713
# epoch 16 step 7500 loss 0.0692
# epoch 17 step 7600 loss 0.0643
# epoch 17 step 7700 loss 0.0657
# epoch 17 step 7800 loss 0.0647
# epoch 17 step 7900 loss 0.0650
# epoch 18 step 8000 loss 0.0645
# epoch 18 step 8100 loss 0.0610
# epoch 18 step 8200 loss 0.0606
# epoch 18 step 8300 loss 0.0620
# epoch 18 step 8400 loss 0.0617
# epoch 19 step 8500 loss 0.0578
# epoch 19 step 8600 loss 0.0575
# epoch 19 step 8700 loss 0.0572
# epoch 19 step 8800 loss 0.0575
# epoch 19 step 8900 loss 0.0576
# epoch 20 step 9000 loss 0.0515
# [train eval] step 9000 loss 0.0515 cls 0.9730 iou 0.9963 det 0.9729 exact 0.9195
# [test eval] step 9000 loss 0.1267 cls 0.9458 iou 0.9933 det 0.9457 exact 0.8492
# saved new best heatmap model, exact_set_acc 0.8492
# epoch 20 step 9100 loss 0.3475
# epoch 20 step 9200 loss 0.0947
# epoch 20 step 9300 loss 0.0772
# epoch 21 step 9400 loss 0.0705
# epoch 21 step 9500 loss 0.0563
# epoch 21 step 9600 loss 0.0526
# epoch 21 step 9700 loss 0.0506
# epoch 21 step 9800 loss 0.0499
# epoch 22 step 9900 loss 0.0467
# epoch 22 step 10000 loss 0.0447
# epoch 22 step 10100 loss 0.0452
# epoch 22 step 10200 loss 0.0462
# epoch 22 step 10300 loss 0.0469
# epoch 23 step 10400 loss 0.0428
# epoch 23 step 10500 loss 0.0425
# epoch 23 step 10600 loss 0.0422
# epoch 23 step 10700 loss 0.0443
# epoch 24 step 10800 loss 0.0430
# epoch 24 step 10900 loss 0.0400
# epoch 24 step 11000 loss 0.0404
# epoch 24 step 11100 loss 0.0409
# epoch 24 step 11200 loss 0.0420
# epoch 25 step 11300 loss 0.0417
# epoch 25 step 11400 loss 0.0382
# epoch 25 step 11500 loss 0.0379
# epoch 25 step 11600 loss 0.0392
# epoch 25 step 11700 loss 0.0396
# epoch 26 step 11800 loss 0.0372
# epoch 26 step 11900 loss 0.0352
# epoch 26 step 12000 loss 0.0371
# [train eval] step 12000 loss 0.0443 cls 0.9757 iou 0.9960 det 0.9755 exact 0.9293
# [test eval] step 12000 loss 0.1486 cls 0.9426 iou 0.9952 det 0.9426 exact 0.8391
# epoch 26 step 12100 loss 0.1222
# epoch 27 step 12200 loss 0.0526
# epoch 27 step 12300 loss 0.0359
# epoch 27 step 12400 loss 0.0333
# epoch 27 step 12500 loss 0.0317
# epoch 27 step 12600 loss 0.0321
# epoch 28 step 12700 loss 0.0308
# epoch 28 step 12800 loss 0.0285
# epoch 28 step 12900 loss 0.0294
# epoch 28 step 13000 loss 0.0308
# epoch 28 step 13100 loss 0.0309
# epoch 29 step 13200 loss 0.0290
# epoch 29 step 13300 loss 0.0279
# epoch 29 step 13400 loss 0.0290
# epoch 29 step 13500 loss 0.0310
# epoch 29 step 13600 loss 0.0318
# epoch 30 step 13700 loss 0.0258
# epoch 30 step 13800 loss 0.0279
# epoch 30 step 13900 loss 0.0280
# epoch 30 step 14000 loss 0.0295
# epoch 31 step 14100 loss 0.0279
# epoch 31 step 14200 loss 0.0234
# epoch 31 step 14300 loss 0.0265
# epoch 31 step 14400 loss 0.0277
# epoch 31 step 14500 loss 0.0269
# epoch 32 step 14600 loss 0.0239
# epoch 32 step 14700 loss 0.0218
# epoch 32 step 14800 loss 0.0244
# epoch 32 step 14900 loss 0.0262
# epoch 32 step 15000 loss 0.0258
# [train eval] step 15000 loss 0.0295 cls 0.9891 iou 0.9963 det 0.9891 exact 0.9676
# [test eval] step 15000 loss 0.1682 cls 0.9477 iou 0.9942 det 0.9477 exact 0.8543
# saved new best heatmap model, exact_set_acc 0.8543
# epoch 33 step 15100 loss 0.0254
# epoch 33 step 15200 loss 0.0219
# epoch 33 step 15300 loss 0.0225
# epoch 33 step 15400 loss 0.0241
# epoch 34 step 15500 loss 0.0221
# epoch 34 step 15600 loss 0.0176
# epoch 34 step 15700 loss 0.0197
# epoch 34 step 15800 loss 0.0214
# epoch 34 step 15900 loss 0.0221
# epoch 35 step 16000 loss 0.0189
# epoch 35 step 16100 loss 0.0169
# epoch 35 step 16200 loss 0.0199
# epoch 35 step 16300 loss 0.0190
# epoch 35 step 16400 loss 0.0207
# epoch 36 step 16500 loss 0.0151
# epoch 36 step 16600 loss 0.0153
# epoch 36 step 16700 loss 0.0179
# epoch 36 step 16800 loss 0.0169
# epoch 37 step 16900 loss 0.0176
# epoch 37 step 17000 loss 0.0151
# epoch 37 step 17100 loss 0.0147
# epoch 37 step 17200 loss 0.0154
# epoch 37 step 17300 loss 0.0174
# epoch 38 step 17400 loss 0.0146
# epoch 38 step 17500 loss 0.0126
# epoch 38 step 17600 loss 0.0150
# epoch 38 step 17700 loss 0.0145
# epoch 38 step 17800 loss 0.0151
# epoch 39 step 17900 loss 0.0125
# epoch 39 step 18000 loss 0.0118
# [train eval] step 18000 loss 0.0184 cls 0.9948 iou 0.9980 det 0.9948 exact 0.9848
# [test eval] step 18000 loss 0.2326 cls 0.9430 iou 0.9959 det 0.9430 exact 0.8395
# epoch 39 step 18100 loss 0.0555
# epoch 39 step 18200 loss 0.0191
# epoch 40 step 18300 loss 0.0197
# epoch 40 step 18400 loss 0.0089
# epoch 40 step 18500 loss 0.0077
# epoch 40 step 18600 loss 0.0076
# epoch 40 step 18700 loss 0.0085
# epoch 41 step 18800 loss 0.0083
# epoch 41 step 18900 loss 0.0059
# epoch 41 step 19000 loss 0.0064
# epoch 41 step 19100 loss 0.0076
# epoch 41 step 19200 loss 0.0102
# epoch 42 step 19300 loss 0.0087
# epoch 42 step 19400 loss 0.0071
# epoch 42 step 19500 loss 0.0083
# epoch 42 step 19600 loss 0.0103
# epoch 43 step 19700 loss 0.0112
# epoch 43 step 19800 loss 0.0066
# epoch 43 step 19900 loss 0.0064
# epoch 43 step 20000 loss 0.0083
# epoch 43 step 20100 loss 0.0090
# epoch 44 step 20200 loss 0.0092
# epoch 44 step 20300 loss 0.0067
# epoch 44 step 20400 loss 0.0072
# epoch 44 step 20500 loss 0.0094
# epoch 44 step 20600 loss 0.0107
# epoch 45 step 20700 loss 0.0081
# epoch 45 step 20800 loss 0.0061
# epoch 45 step 20900 loss 0.0066
# epoch 45 step 21000 loss 0.0077
# [train eval] step 21000 loss 0.0191 cls 0.9953 iou 0.9985 det 0.9953 exact 0.9859
# [test eval] step 21000 loss 0.2897 cls 0.9440 iou 0.9964 det 0.9440 exact 0.8410
# epoch 45 step 21100 loss 0.0360
# epoch 46 step 21200 loss 0.0090
# epoch 46 step 21300 loss 0.0048
# epoch 46 step 21400 loss 0.0045
# epoch 46 step 21500 loss 0.0042
# epoch 47 step 21600 loss 0.0039
# epoch 47 step 21700 loss 0.0029
# epoch 47 step 21800 loss 0.0028
# epoch 47 step 21900 loss 0.0034
# epoch 47 step 22000 loss 0.0032
# epoch 48 step 22100 loss 0.0032
# epoch 48 step 22200 loss 0.0027
# epoch 48 step 22300 loss 0.0030
# epoch 48 step 22400 loss 0.0042
# epoch 48 step 22500 loss 0.0103
# epoch 49 step 22600 loss 0.0081
# epoch 49 step 22700 loss 0.0055
# epoch 49 step 22800 loss 0.0045
# epoch 49 step 22900 loss 0.0043
# epoch 50 step 23000 loss 0.0051
# epoch 50 step 23100 loss 0.0044
# epoch 50 step 23200 loss 0.0046
# epoch 50 step 23300 loss 0.0040
# epoch 50 step 23400 loss 0.0036
# epoch 51 step 23500 loss 0.0043
# epoch 51 step 23600 loss 0.0029
# epoch 51 step 23700 loss 0.0033
# epoch 51 step 23800 loss 0.0042
# epoch 51 step 23900 loss 0.0061
# epoch 52 step 24000 loss 0.0060
# [train eval] step 24000 loss 0.0182 cls 0.9967 iou 0.9990 det 0.9967 exact 0.9902
# [test eval] step 24000 loss 0.3058 cls 0.9436 iou 0.9963 det 0.9436 exact 0.8422
# epoch 52 step 24100 loss 0.0161
# epoch 52 step 24200 loss 0.0131
# epoch 52 step 24300 loss 0.0059
# epoch 53 step 24400 loss 0.0047
# epoch 53 step 24500 loss 0.0022
# epoch 53 step 24600 loss 0.0020
# epoch 53 step 24700 loss 0.0021
# epoch 53 step 24800 loss 0.0019
# epoch 54 step 24900 loss 0.0017
# epoch 54 step 25000 loss 0.0014
# epoch 54 step 25100 loss 0.0014
# epoch 54 step 25200 loss 0.0014
# epoch 54 step 25300 loss 0.0015
# epoch 55 step 25400 loss 0.0013
# epoch 55 step 25500 loss 0.0011
# epoch 55 step 25600 loss 0.0012
# epoch 55 step 25700 loss 0.0013
# epoch 56 step 25800 loss 0.0013
# epoch 56 step 25900 loss 0.0010
# epoch 56 step 26000 loss 0.0011
# epoch 56 step 26100 loss 0.0012
# epoch 56 step 26200 loss 0.0018
# epoch 57 step 26300 loss 0.0032
# epoch 57 step 26400 loss 0.0047
# epoch 57 step 26500 loss 0.0039
# epoch 57 step 26600 loss 0.0037
# epoch 57 step 26700 loss 0.0029
# epoch 58 step 26800 loss 0.0023
# epoch 58 step 26900 loss 0.0016
# epoch 58 step 27000 loss 0.0014
# [train eval] step 27000 loss 0.0160 cls 0.9970 iou 0.9991 det 0.9970 exact 0.9910
# [test eval] step 27000 loss 0.3647 cls 0.9445 iou 0.9967 det 0.9445 exact 0.8457
# epoch 58 step 27100 loss 0.0084
# epoch 58 step 27200 loss 0.0106
# epoch 59 step 27300 loss 0.0022
# epoch 59 step 27400 loss 0.0013
# epoch 59 step 27500 loss 0.0013
# epoch 59 step 27600 loss 0.0012
# epoch 60 step 27700 loss 0.0010
# epoch 60 step 27800 loss 0.0009
# epoch 60 step 27900 loss 0.0008
# epoch 60 step 28000 loss 0.0008
# epoch 60 step 28100 loss 0.0008
# epoch 61 step 28200 loss 0.0007
# epoch 61 step 28300 loss 0.0007
# epoch 61 step 28400 loss 0.0006
# epoch 61 step 28500 loss 0.0007
# epoch 61 step 28600 loss 0.0006
# epoch 62 step 28700 loss 0.0006
# epoch 62 step 28800 loss 0.0005
# epoch 62 step 28900 loss 0.0006
# epoch 62 step 29000 loss 0.0005
# epoch 63 step 29100 loss 0.0005
# epoch 63 step 29200 loss 0.0004
# epoch 63 step 29300 loss 0.0005
# epoch 63 step 29400 loss 0.0005
# epoch 63 step 29500 loss 0.0006
# epoch 64 step 29600 loss 0.0005
# epoch 64 step 29700 loss 0.0005
# epoch 64 step 29800 loss 0.0004
# epoch 64 step 29900 loss 0.0005
# epoch 64 step 30000 loss 0.0006
# [train eval] step 30000 loss 0.0198 cls 0.9979 iou 0.9990 det 0.9979 exact 0.9941
# [test eval] step 30000 loss 0.4158 cls 0.9456 iou 0.9972 det 0.9456 exact 0.8469
# epoch 65 step 30100 loss 0.0024
# epoch 65 step 30200 loss 0.0009
# epoch 65 step 30300 loss 0.0009
# epoch 65 step 30400 loss 0.0007
# epoch 66 step 30500 loss 0.0006
# epoch 66 step 30600 loss 0.0004
# epoch 66 step 30700 loss 0.0004
# epoch 66 step 30800 loss 0.0003
# epoch 66 step 30900 loss 0.0004
# epoch 67 step 31000 loss 0.0003
# epoch 67 step 31100 loss 0.0003
# epoch 67 step 31200 loss 0.0003
# epoch 67 step 31300 loss 0.0003
# epoch 67 step 31400 loss 0.0003
# epoch 68 step 31500 loss 0.0002
# epoch 68 step 31600 loss 0.0002
# epoch 68 step 31700 loss 0.0003
# epoch 68 step 31800 loss 0.0003
# epoch 69 step 31900 loss 0.0004
# epoch 69 step 32000 loss 0.0002
# epoch 69 step 32100 loss 0.0002
# epoch 69 step 32200 loss 0.0003
# epoch 69 step 32300 loss 0.0003
# epoch 70 step 32400 loss 0.0002
# epoch 70 step 32500 loss 0.0002
# epoch 70 step 32600 loss 0.0002
# epoch 70 step 32700 loss 0.0002
# epoch 70 step 32800 loss 0.0002
# epoch 71 step 32900 loss 0.0002
# epoch 71 step 33000 loss 0.0002
# [train eval] step 33000 loss 0.0230 cls 0.9979 iou 0.9991 det 0.9979 exact 0.9941
# [test eval] step 33000 loss 0.4589 cls 0.9474 iou 0.9970 det 0.9473 exact 0.8523
# epoch 71 step 33100 loss 0.0005
# epoch 71 step 33200 loss 0.0017
# epoch 72 step 33300 loss 0.0004
# epoch 72 step 33400 loss 0.0002
# epoch 72 step 33500 loss 0.0002
# epoch 72 step 33600 loss 0.0002
# epoch 72 step 33700 loss 0.0001
# epoch 73 step 33800 loss 0.0003
# epoch 73 step 33900 loss 0.0001
# epoch 73 step 34000 loss 0.0001
# epoch 73 step 34100 loss 0.0001
# epoch 73 step 34200 loss 0.0001
# epoch 74 step 34300 loss 0.0002
# epoch 74 step 34400 loss 0.0002
# epoch 74 step 34500 loss 0.0001
# epoch 74 step 34600 loss 0.0001
# epoch 74 step 34700 loss 0.0001
# epoch 75 step 34800 loss 0.0001
# epoch 75 step 34900 loss 0.0002
# epoch 75 step 35000 loss 0.0001
# epoch 75 step 35100 loss 0.0002
# epoch 76 step 35200 loss 0.0002
# epoch 76 step 35300 loss 0.0001
# epoch 76 step 35400 loss 0.0002
# epoch 76 step 35500 loss 0.0001
# epoch 76 step 35600 loss 0.0001
# epoch 77 step 35700 loss 0.0001
# epoch 77 step 35800 loss 0.0001
# epoch 77 step 35900 loss 0.0001
# epoch 77 step 36000 loss 0.0001
# [train eval] step 36000 loss 0.0245 cls 0.9979 iou 0.9992 det 0.9979 exact 0.9941
# [test eval] step 36000 loss 0.4777 cls 0.9471 iou 0.9975 det 0.9471 exact 0.8516
# epoch 77 step 36100 loss 0.0001
# epoch 78 step 36200 loss 0.0001
# epoch 78 step 36300 loss 0.0001
# epoch 78 step 36400 loss 0.0001
# epoch 78 step 36500 loss 0.0001
# epoch 79 step 36600 loss 0.0001
# epoch 79 step 36700 loss 0.0001
# epoch 79 step 36800 loss 0.0001
# epoch 79 step 36900 loss 0.0001
# epoch 79 step 37000 loss 0.0001
# epoch 80 step 37100 loss 0.0001
# epoch 80 step 37200 loss 0.0001
# epoch 80 step 37300 loss 0.0001
# epoch 80 step 37400 loss 0.0001
# epoch 80 step 37500 loss 0.0001
# done
# best checkpoint is ./runs/best_model_heatmap.pt
# final checkpoint is ./runs/model_final_heatmap.pt
# final train metrics {'loss': 0.029319557826966047, 'cls_acc': 0.9974666666666666, 'mean_iou': 0.9992717610677083, 'mean_box_l1': 9.427083333333333e-05, 'det_acc': 0.9974666666666666, 'exact_set_acc': 0.9926, 'num_images': 5000, 'num_objects': 15000}
# final test metrics {'loss': 0.4851562827825546, 'cls_acc': 0.9438, 'mean_iou': 0.9967214029947916, 'mean_box_l1': 0.0005572916666666667, 'det_acc': 0.9438, 'exact_set_acc': 0.8424, 'num_images': 5000, 'num_objects': 15000}

# %%
save_checkpoint_heatmap(
    "./runs/centerCNN_model_final_heatmap.pt",
    model=model,
    emnist_split=emnist_split,
    num_classes=num_classes,
    class_names=class_names,
    k=k,
    canvas_size=canvas_size,
    object_size=object_size,
    extra={
        "epoch": epochs,
        "global_step": global_step,
        "final_train_metrics": final_train_metrics,
        "final_val_metrics": final_val_metrics,
        "history": history,
        "target_radius": target_radius,
    },
)

# %%
# ============================================================
# Exp 3 TD unbinding with trained heatmap model as visual encoder
#
# Scene code:
#   one letter = one-hot(label) + one-hot(x) + one-hot(y)
#   3 letters  = concatenation of 3 letter codes
#   total active bits = 9
#
# This code assumes the CenterHeatmapDetector code above is already defined.
# It uses:
#   ./runs/model_latest_heatmap.pt
# ============================================================

import os
import json
import numpy as np
import torch
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
from torch.utils.data import DataLoader


# ============================================================
# Config
# ============================================================

TD_CACHE_DIR = "./td_heatmap_encoder_results"
os.makedirs(TD_CACHE_DIR, exist_ok=True)

MODEL_PATH = "./runs/model_latest_heatmap.pt"

canvas_size = 64
object_size = 28
k = 3
emnist_split = "letters"

N_LETTERS = 26
IMG_SIZE = canvas_size

INPUT_SIZE = N_LETTERS + IMG_SIZE + IMG_SIZE
FULL_SIZE = INPUT_SIZE * 3

X_RANGE_EXP3 = [
    1, 10, 100, 1000, 2000, 5000, 10000,
    20000, 50000, 100000, 200000, 500000
]

HP_SETS = [
    {
        "n_post": 10000,
        "p": 0.0005,
        "label": "N=10,000, fq=0.05%",
        "color": "tab:blue",
    },
    {
        "n_post": 50000,
        "p": 0.0002,
        "label": "N=50,000, fq=0.02%",
        "color": "tab:orange",
    },
]

EVAL_MAX_ITEMS_EXP3 = 10000
threshold_exp3 = 7

batch_size_encoder = 512
batch_size_data = 512

max_exp3 = max(X_RANGE_EXP3)


# ============================================================
# Safe cache helpers
# ============================================================

def save_npz_safe(path, **kwargs):
    tmp_path = path + ".tmp.npz"
    np.savez_compressed(tmp_path, **kwargs)

    if os.path.exists(path):
        os.remove(path)

    os.rename(tmp_path, path)


def load_npz_dict(path):
    data = np.load(path, allow_pickle=True)
    return {k: data[k] for k in data.files}


def save_json(path, obj):
    tmp_path = path + ".tmp"

    with open(tmp_path, "w") as f:
        json.dump(obj, f, indent=2)

    if os.path.exists(path):
        os.remove(path)

    os.rename(tmp_path, path)


# ============================================================
# Load trained heatmap model
# ============================================================

def load_heatmap_encoder(model_path=MODEL_PATH, device=None):
    if device is None:
        device = "cuda" if torch.cuda.is_available() else "cpu"

    ckpt = torch.load(model_path, map_location=device)

    model = CenterHeatmapDetector(
        num_classes=ckpt.get("num_classes", 26),
        base_ch=64,
        canvas_size=ckpt.get("canvas_size", 64),
        object_size=ckpt.get("object_size", 28),
    ).to(device)

    if "model_state_dict" in ckpt:
        state = ckpt["model_state_dict"]
    else:
        state = ckpt["model"]

    model.load_state_dict(state)
    model.eval()

    print("Loaded encoder:", model_path)
    print("checkpoint epoch:", ckpt.get("epoch", None))
    print("checkpoint global_step:", ckpt.get("global_step", None))

    return model, ckpt, device


model_encoder, model_ckpt, device = load_heatmap_encoder(MODEL_PATH)


# ============================================================
# Encoding without color
# ============================================================

def encode_letter_no_color(letter_idx, x, y):
    # One can pad many zeros to make this vec a 10,000 dimensional long sparse vector
    vec = np.zeros(INPUT_SIZE, dtype=np.uint8)

    if letter_idx is not None:
        vec[int(letter_idx)] = 1

    if x is not None:
        vec[N_LETTERS + int(x)] = 1

    if y is not None:
        vec[N_LETTERS + IMG_SIZE + int(y)] = 1

    return vec


def canonicalize_scene_labelxy(scene):
    scene = [tuple(map(int, row)) for row in scene]
    return sorted(scene, key=lambda z: (z[1], z[2], z[0]))


def encode_full_scene_no_color(scene):
    scene = canonicalize_scene_labelxy(scene)

    return np.concatenate([
        encode_letter_no_color(letter_idx, x, y)
        for letter_idx, x, y in scene
    ]).astype(np.uint8)


def scenes_to_full_vectors_no_color_cached(scenes, cache_path, desc="encoding scenes"):
    if os.path.exists(cache_path):
        print("Loading encoded vectors:", cache_path)
        return np.load(cache_path)

    arr = np.zeros((len(scenes), FULL_SIZE), dtype=np.uint8)

    for i in tqdm(range(len(scenes)), desc=desc):
        arr[i] = encode_full_scene_no_color(scenes[i])

    np.save(cache_path, arr)
    print("Saved encoded vectors:", cache_path)

    return arr


def wta_decode_full_no_color(reconstruct):
    decoded = np.zeros(FULL_SIZE, dtype=np.uint8)

    for part in range(3):
        base = part * INPUT_SIZE

        i = np.argmax(reconstruct[base : base + N_LETTERS])
        decoded[base + i] = 1

        offset = base + N_LETTERS
        i = np.argmax(reconstruct[offset : offset + IMG_SIZE])
        decoded[offset + i] = 1

        offset += IMG_SIZE
        i = np.argmax(reconstruct[offset : offset + IMG_SIZE])
        decoded[offset + i] = 1

    return decoded


def full_vector_to_scene_no_color(vec):
    scene = []

    for part in range(3):
        base = part * INPUT_SIZE

        letter_idx = int(np.argmax(vec[base : base + N_LETTERS]))

        offset = base + N_LETTERS
        x = int(np.argmax(vec[offset : offset + IMG_SIZE]))

        offset += IMG_SIZE
        y = int(np.argmax(vec[offset : offset + IMG_SIZE]))

        scene.append((letter_idx, x, y))

    return canonicalize_scene_labelxy(scene)

from itertools import permutations

def scene_match_tolerant_labelxy(pred_scene, target_scene, xy_tol=1):
    """
    pred_scene and target_scene:
        list of 3 tuples:
            (letter_idx, x, y)

    A predicted object is correct if:
        label matches
        |x_pred - x_gt| <= xy_tol
        |y_pred - y_gt| <= xy_tol

    Because object order is not meaningful, we try all 3! matchings.
    """

    pred_scene = [tuple(map(int, row)) for row in pred_scene]
    target_scene = [tuple(map(int, row)) for row in target_scene]

    K = len(pred_scene)

    for p in permutations(range(K)):
        ok = True

        for i in range(K):
            lp, xp, yp = pred_scene[i]
            lt, xt, yt = target_scene[p[i]]

            if lp != lt:
                ok = False
                break

            if abs(xp - xt) > xy_tol:
                ok = False
                break

            if abs(yp - yt) > xy_tol:
                ok = False
                break

        if ok:
            return True

    return False


def vector_match_tolerant_labelxy(pred_vec, target_vec, xy_tol=1):
    pred_scene = full_vector_to_scene_no_color(pred_vec)
    target_scene = full_vector_to_scene_no_color(target_vec)

    return scene_match_tolerant_labelxy(
        pred_scene=pred_scene,
        target_scene=target_scene,
        xy_tol=xy_tol,
    )

# ============================================================
# Convert boxes to integer centers
# ============================================================

def boxes_to_integer_centers_numpy(boxes, canvas_size=64):
    cx = np.rint((boxes[..., 0] + boxes[..., 2]) * 0.5 * canvas_size).astype(np.int16)
    cy = np.rint((boxes[..., 1] + boxes[..., 3]) * 0.5 * canvas_size).astype(np.int16)

    cx = np.clip(cx, 0, canvas_size - 1)
    cy = np.clip(cy, 0, canvas_size - 1)

    return cx, cy


@torch.no_grad()
def detect_batch_as_labelxy(model, x, device, k=3, canvas_size=64, object_size=28):
    x = x.to(device, non_blocking=True)

    logits = model(x)

    pred_boxes, pred_labels, pred_scores = decode_heatmap_topk(
        logits=logits,
        k=k,
        canvas_size=canvas_size,
        object_size=object_size,
    )

    pred_boxes = pred_boxes.detach().cpu().numpy()
    pred_labels = pred_labels.detach().cpu().numpy().astype(np.int16)

    pred_cx, pred_cy = boxes_to_integer_centers_numpy(
        pred_boxes,
        canvas_size=canvas_size,
    )

    B = pred_labels.shape[0]
    scenes = np.zeros((B, k, 3), dtype=np.int16)

    for i in range(B):
        objs = []

        for j in range(k):
            objs.append((
                int(pred_labels[i, j]),
                int(pred_cx[i, j]),
                int(pred_cy[i, j]),
            ))

        scenes[i] = np.asarray(
            canonicalize_scene_labelxy(objs),
            dtype=np.int16,
        )

    return scenes


def gt_batch_as_labelxy(gt_boxes, gt_labels, canvas_size=64, k=3):
    gt_boxes = gt_boxes.detach().cpu().numpy()
    gt_labels = gt_labels.detach().cpu().numpy().astype(np.int16)

    gt_cx, gt_cy = boxes_to_integer_centers_numpy(
        gt_boxes,
        canvas_size=canvas_size,
    )

    B = gt_labels.shape[0]
    scenes = np.zeros((B, k, 3), dtype=np.int16)

    for i in range(B):
        objs = []

        for j in range(k):
            objs.append((
                int(gt_labels[i, j]),
                int(gt_cx[i, j]),
                int(gt_cy[i, j]),
            ))

        scenes[i] = np.asarray(
            canonicalize_scene_labelxy(objs),
            dtype=np.int16,
        )

    return scenes


# ============================================================
# Build train-only or test-only visual-encoder pools
# ============================================================
def build_heatmap_encoder_pool_cached(
    split_name,
    train_flag,
    max_images,
    seed,
    model,
    device,
    rebuild=False,
    save_every_batches=20,
):
    """
    Builds and caches:
        gt_scenes  : ground-truth symbolic scenes
        det_scenes : scenes predicted by the heatmap encoder
        gt_full    : ground-truth 9-hot vectors
        det_full   : encoder-produced 9-hot vectors

    It saves partial progress during encoding.
    If interrupted, it resumes next time.
    """

    scene_cache_path = os.path.join(
        TD_CACHE_DIR,
        f"exp3_{split_name}_scenes_n{max_images}_seed{seed}.npz"
    )

    det_full_path = os.path.join(
        TD_CACHE_DIR,
        f"exp3_{split_name}_det_full_n{max_images}_seed{seed}.npy"
    )

    gt_full_path = os.path.join(
        TD_CACHE_DIR,
        f"exp3_{split_name}_gt_full_n{max_images}_seed{seed}.npy"
    )

    # --------------------------------------------------------
    # Case 1: full scene cache already exists
    # --------------------------------------------------------

    if os.path.exists(scene_cache_path) and (not rebuild):
        obj = load_npz_dict(scene_cache_path)

        gt_scenes = obj["gt_scenes"]
        det_scenes = obj["det_scenes"]
        done = int(obj.get("done", max_images))

        print("Loaded scene cache:", scene_cache_path)
        print(f"done={done}/{max_images}")

        if done >= max_images:
            gt_full = scenes_to_full_vectors_no_color_cached(
                gt_scenes,
                cache_path=gt_full_path,
                desc=f"encoding {split_name} GT full vectors",
            )

            det_full = scenes_to_full_vectors_no_color_cached(
                det_scenes,
                cache_path=det_full_path,
                desc=f"encoding {split_name} visual-encoder full vectors",
            )

            return gt_scenes, det_scenes, det_full, gt_full

    # --------------------------------------------------------
    # Case 2: no cache, or partial cache
    # --------------------------------------------------------

    if os.path.exists(scene_cache_path) and (not rebuild):
        obj = load_npz_dict(scene_cache_path)

        gt_scenes = obj["gt_scenes"]
        det_scenes = obj["det_scenes"]
        done = int(obj.get("done", 0))

        print("Resuming scene encoding from cache:", scene_cache_path)
        print(f"done={done}/{max_images}")

    else:
        gt_scenes = np.zeros((max_images, k, 3), dtype=np.int16)
        det_scenes = np.zeros((max_images, k, 3), dtype=np.int16)
        done = 0

        print("Starting new scene encoding:", scene_cache_path)

    # --------------------------------------------------------
    # Build dataset
    # --------------------------------------------------------

    ds = ThreeCharEMNIST(
        root="./data",
        train=train_flag,
        split=emnist_split,
        canvas_size=canvas_size,
        chars_per_image=k,
        length=max_images,
        seed=seed,
        allow_overlap=False,
        placement_tries=80,
        min_separation=2,
        augment=False,
    )

    loader = DataLoader(
        ds,
        batch_size=batch_size_encoder,
        shuffle=False,
        num_workers=0,
        pin_memory=True,
    )

    model.eval()

    batch_counter = 0

    # --------------------------------------------------------
    # Resume by skipping already-finished batches
    # --------------------------------------------------------

    current_start = 0

    for x, gt_boxes, gt_labels in tqdm(
        loader,
        desc=f"encoding {split_name} with heatmap model",
    ):
        B = x.shape[0]
        current_end = current_start + B

        if current_end <= done:
            current_start = current_end
            continue

        # In normal resume cases, current_start should equal done.
        # This handles a rare case where done falls inside a batch.
        if current_start < done < current_end:
            keep_from = done - current_start

            x = x[keep_from:]
            gt_boxes = gt_boxes[keep_from:]
            gt_labels = gt_labels[keep_from:]

            current_start = done
            B = x.shape[0]
            current_end = current_start + B

        gt_scenes[current_start:current_end] = gt_batch_as_labelxy(
            gt_boxes=gt_boxes,
            gt_labels=gt_labels,
            canvas_size=canvas_size,
            k=k,
        )

        det_scenes[current_start:current_end] = detect_batch_as_labelxy(
            model=model,
            x=x,
            device=device,
            k=k,
            canvas_size=canvas_size,
            object_size=object_size,
        )

        done = current_end
        batch_counter += 1

        if batch_counter % save_every_batches == 0 or done >= max_images:
            save_npz_safe(
                scene_cache_path,
                gt_scenes=gt_scenes,
                det_scenes=det_scenes,
                done=np.array(done, dtype=np.int64),
            )

            print(f"Saved partial scene cache: done={done}/{max_images}")

        current_start = current_end

    # --------------------------------------------------------
    # Final accuracy check
    # --------------------------------------------------------

    exact_scene_acc = float(
        np.mean(np.all(det_scenes == gt_scenes, axis=(1, 2)))
    )

    print(f"{split_name} visual encoder exact scene acc: {exact_scene_acc:.4f}")

    save_npz_safe(
        scene_cache_path,
        gt_scenes=gt_scenes,
        det_scenes=det_scenes,
        done=np.array(max_images, dtype=np.int64),
        exact_scene_acc=np.array(exact_scene_acc, dtype=np.float32),
    )

    save_json(
        scene_cache_path.replace(".npz", "_meta.json"),
        {
            "split_name": split_name,
            "train_flag": bool(train_flag),
            "max_images": int(max_images),
            "seed": int(seed),
            "model_path": MODEL_PATH,
            "exact_scene_acc": exact_scene_acc,
            "code": "letter one-hot + x one-hot + y one-hot",
        },
    )

    print("Saved final scene cache:", scene_cache_path)

    # --------------------------------------------------------
    # Build or reload full 9-hot vectors
    # --------------------------------------------------------

    gt_full = scenes_to_full_vectors_no_color_cached(
        gt_scenes,
        cache_path=gt_full_path,
        desc=f"encoding {split_name} GT full vectors",
    )

    det_full = scenes_to_full_vectors_no_color_cached(
        det_scenes,
        cache_path=det_full_path,
        desc=f"encoding {split_name} visual-encoder full vectors",
    )

    return gt_scenes, det_scenes, det_full, gt_full

# ============================================================
# Memory model
# ============================================================

def memory_update(W_ff, W_fb, full_input, rng, p):
    selected = rng.random(W_ff.shape[0]) <= p

    if not np.any(selected):
        return

    sel_idx = np.flatnonzero(selected)
    active_idx = np.flatnonzero(full_input)

    if len(active_idx) == 0:
        return

    sub = W_ff[np.ix_(sel_idx, active_idx)]
    set_to_1 = sub == 0

    W_ff[np.ix_(sel_idx, active_idx)] = 1 - sub

    rows, cols = np.where(set_to_1.T)

    if len(rows) > 0:
        W_fb[active_idx[rows], sel_idx[cols]] = 1


def evaluate_memory_td_no_color(
    W_ff,
    W_fb,
    cues,
    targets,
    threshold,
    max_items=None,
    xy_tol=1,
):
    n_total = len(cues)

    if max_items is None or max_items >= n_total:
        eval_idx = np.arange(n_total)
    else:
        eval_idx = np.linspace(0, n_total - 1, max_items).astype(int)

    W_ff_i = W_ff.astype(np.int16, copy=False)
    W_fb_i = W_fb.astype(np.int16, copy=False)

    bit_accs = []
    exacts = []
    scene_exacts = []
    scene_tolerant_exacts = []

    for idx in eval_idx:
        cue = cues[idx].astype(np.int16, copy=False)
        target = targets[idx].astype(np.uint8, copy=False)

        hidden = (W_ff_i @ cue) > threshold
        reconstruct = W_fb_i @ hidden.astype(np.int16)

        decoded = wta_decode_full_no_color(reconstruct)

        bit_accs.append(np.mean(decoded == target))
        exacts.append(float(np.array_equal(decoded, target)))

        decoded_scene = full_vector_to_scene_no_color(decoded)
        target_scene = full_vector_to_scene_no_color(target)

        scene_exacts.append(float(decoded_scene == target_scene))

        tolerant_ok = scene_match_tolerant_labelxy(
            pred_scene=decoded_scene,
            target_scene=target_scene,
            xy_tol=xy_tol,
        )

        scene_tolerant_exacts.append(float(tolerant_ok))

    return {
        "bit_acc": float(np.mean(bit_accs)),
        "exact_acc": float(np.mean(exacts)),
        "scene_exact_acc": float(np.mean(scene_exacts)),
        "scene_tolerant_exact_acc": float(np.mean(scene_tolerant_exacts)),
        "xy_tol": int(xy_tol),
        "n_eval": int(len(eval_idx)),
    }


def run_curve_incremental_checkpointed_td_no_color(
    train_vectors,
    cue_vectors,
    target_vectors,
    x_range,
    n_post,
    p,
    threshold,
    seed=0,
    max_eval_items=None,
    cache_name="experiment",
    cache_dir=TD_CACHE_DIR,
    force_restart=False,
):
    seed=10
    os.makedirs(cache_dir, exist_ok=True)

    ckpt_path = os.path.join(
        cache_dir,
        f"{cache_name}_npost{n_post}_p{p}_thr{threshold}_seed{seed}.npz"
    )

    x_range = list(x_range)
    max_n = max(x_range)
    x_set = set(x_range)

    rng = np.random.default_rng(seed)

    if os.path.exists(ckpt_path) and not force_restart:
        print("Loading memory checkpoint:", ckpt_path)

        ckpt = np.load(ckpt_path, allow_pickle=True)

        W_ff = ckpt["W_ff"]
        W_fb = ckpt["W_fb"]
        start_i = int(ckpt["current_i"])

        results = {
            "x_range": ckpt["x_range"].tolist(),
            "bit_acc": ckpt["bit_acc"].tolist(),
            "exact_acc": ckpt["exact_acc"].tolist(),
            "scene_exact_acc": ckpt["scene_exact_acc"].tolist(),
            "scene_tolerant_exact_acc": ckpt["scene_tolerant_exact_acc"].tolist()
                if "scene_tolerant_exact_acc" in ckpt.files else [],
            "n_eval": ckpt["n_eval"].tolist(),
        }

        rng_state = ckpt["rng_state"].item()
        rng.bit_generator.state = rng_state

        print(f"Resuming from sample {start_i}")
        print("Finished datapoints:", results["x_range"])

    else:
        print("Starting new memory run:", ckpt_path)

        W_ff = np.zeros((n_post, FULL_SIZE), dtype=np.uint8)
        W_fb = np.zeros((FULL_SIZE, n_post), dtype=np.uint8)

        start_i = 0

        results = {
            "x_range": [],
            "bit_acc": [],
            "exact_acc": [],
            "scene_exact_acc": [],
            "scene_tolerant_exact_acc": [],
            "n_eval": [],
        }

    for i in tqdm(range(start_i, max_n), desc=f"training {cache_name}, N={n_post}, p={p}"):
        memory_update(
            W_ff=W_ff,
            W_fb=W_fb,
            full_input=train_vectors[i],
            rng=rng,
            p=p,
        )

        current_n = i + 1

        if current_n in x_set:
            stats = evaluate_memory_td_no_color(
                W_ff=W_ff,
                W_fb=W_fb,
                cues=cue_vectors[:current_n],
                targets=target_vectors[:current_n],
                threshold=threshold,
                max_items=max_eval_items,
                xy_tol=2,
            )


            print(
                f"{cache_name}, N={n_post}, p={p}, samples={current_n}, "
                f"bit_acc={stats['bit_acc']:.4f}, "
                f"exact_acc={stats['exact_acc']:.4f}, "
                f"scene_exact_acc={stats['scene_exact_acc']:.4f}, "
                f"scene_tol_acc={stats['scene_tolerant_exact_acc']:.4f}, "
                f"n_eval={stats['n_eval']}"
            )

            if current_n not in results["x_range"]:
                results["x_range"].append(current_n)
                results["bit_acc"].append(stats["bit_acc"])
                results["exact_acc"].append(stats["exact_acc"])
                results["scene_exact_acc"].append(stats["scene_exact_acc"])
                results["scene_tolerant_exact_acc"].append(stats["scene_tolerant_exact_acc"])
                results["n_eval"].append(stats["n_eval"])



            save_npz_safe(
                ckpt_path,
                W_ff=W_ff,
                W_fb=W_fb,
                current_i=np.array(current_n, dtype=np.int64),
                x_range=np.asarray(results["x_range"]),
                bit_acc=np.asarray(results["bit_acc"]),
                exact_acc=np.asarray(results["exact_acc"]),
                scene_exact_acc=np.asarray(results["scene_exact_acc"]),
                scene_tolerant_exact_acc=np.asarray(results["scene_tolerant_exact_acc"]),
                n_eval=np.asarray(results["n_eval"]),
                rng_state=np.array(rng.bit_generator.state, dtype=object),
            )

            print("Saved memory checkpoint:", ckpt_path)

    final_results = {
        "x_range": np.asarray(results["x_range"]),
        "bit_acc": np.asarray(results["bit_acc"]),
        "exact_acc": np.asarray(results["exact_acc"]),
        "scene_exact_acc": np.asarray(results["scene_exact_acc"]),
        "scene_tolerant_exact_acc": np.asarray(results["scene_tolerant_exact_acc"]),
        "n_eval": np.asarray(results["n_eval"]),
    }

    final_path = os.path.join(
        cache_dir,
        f"{cache_name}_npost{n_post}_p{p}_thr{threshold}_seed{seed}_final.npy"
    )

    np.save(final_path, final_results, allow_pickle=True)

    print("Saved final memory results:", final_path)

    return final_results


# ============================================================
# Plotting
# ============================================================

def plot_td_pair(res_10000, res_50000, title, xlim=(1, 600000), ylim=(0, 103.5)):
    plt.figure(figsize=(4, 3), dpi=300)

    plt.plot(
        res_10000["x_range"],
        res_10000["scene_exact_acc"] * 100,
        marker="o",
        lw=3,
        label="N=10,000, fq=0.05%",
        color="tab:blue",
        alpha=0.85,
    )

    plt.plot(
        res_50000["x_range"],
        res_50000["scene_exact_acc"] * 100,
        marker="o",
        lw=3,
        label="N=50,000, fq=0.02%",
        color="tab:orange",
        alpha=0.85,
    )

    plt.xscale("log")
    plt.xlim(*xlim)
    plt.ylim(*ylim)

    plt.xlabel("Number of stored canvases")
    plt.ylabel("TD unbinding accuracy / %")
    plt.title(title)
    plt.legend()
    plt.tight_layout()
    plt.show()


# ============================================================
# Prepare data
# ============================================================

print("\n========== Prepare Exp 3 train-letter pool ==========")

gt_scenes_train, det_scenes_train, det_full_train, gt_full_train = build_heatmap_encoder_pool_cached(
    split_name="train_letters",
    train_flag=True,
    max_images=max_exp3,
    seed=333,
    model=model_encoder,
    device=device,
    rebuild=False,
)

rng = np.random.default_rng(2)

perm_train = rng.permutation(len(det_full_train))

det_full_train = det_full_train[perm_train]
gt_full_train = gt_full_train[perm_train]

det_scenes_train = det_scenes_train[perm_train]
gt_scenes_train = gt_scenes_train[perm_train]

print("\n========== Prepare Exp 3 test-letter pool ==========")

gt_scenes_test, det_scenes_test, det_full_test, gt_full_test = build_heatmap_encoder_pool_cached(
    split_name="test_letters",
    train_flag=False,
    max_images=max_exp3,
    seed=444,
    model=model_encoder,
    device=device,
    rebuild=False,
)

rng = np.random.default_rng(2)

perm_test = rng.permutation(len(det_full_test))

det_full_test = det_full_test[perm_test]
gt_full_test = gt_full_test[perm_test]

det_scenes_test = det_scenes_test[perm_test]
gt_scenes_test = gt_scenes_test[perm_test]


# ============================================================
# Run train-only Exp 3
# ============================================================

all_results = {}

print("\n========== Exp 3 TD: train letters only ==========")

for hp in HP_SETS:
    res = run_curve_incremental_checkpointed_td_no_color(
        train_vectors=det_full_train,
        cue_vectors=det_full_train,
        target_vectors=gt_full_train,
        x_range=X_RANGE_EXP3,
        n_post=hp["n_post"],
        p=hp["p"],
        threshold=threshold_exp3,
        seed=3000 + hp["n_post"],
        max_eval_items=EVAL_MAX_ITEMS_EXP3,
        cache_name="centerCNN_exp3_TD_heatmap_encoder_train_letters",
        force_restart=False,
    )

    all_results[f"train_exp3_{hp['n_post']}_{hp['p']}"] = res


# ============================================================
# Run test-only Exp 3
# ============================================================

print("\n========== Exp 3 TD: test letters only ==========")

for hp in HP_SETS:
    res = run_curve_incremental_checkpointed_td_no_color(
        train_vectors=det_full_test,
        cue_vectors=det_full_test,
        target_vectors=gt_full_test,
        x_range=X_RANGE_EXP3,
        n_post=hp["n_post"],
        p=hp["p"],
        threshold=threshold_exp3,
        seed=4000 + hp["n_post"],
        max_eval_items=EVAL_MAX_ITEMS_EXP3,
        cache_name="centerCNN_exp3_TD_heatmap_encoder_test_letters",
        force_restart=False,
    )

    all_results[f"test_exp3_{hp['n_post']}_{hp['p']}"] = res


# ============================================================
# Save and plot
# ============================================================

all_results_path = os.path.join(
    TD_CACHE_DIR,
    "all_exp3_td_heatmap_encoder_results.npy"
)

np.save(all_results_path, all_results, allow_pickle=True)

print("Saved all results:", all_results_path)

plot_td_pair(
    res_10000=all_results["train_exp3_10000_0.0005"],
    res_50000=all_results["train_exp3_50000_0.0002"],
    title="Exp 3 TD: heatmap encoder, train letters",
    xlim=(1, 600000),
    ylim=(0, 103.5),
)

plot_td_pair(
    res_10000=all_results["test_exp3_10000_0.0005"],
    res_50000=all_results["test_exp3_50000_0.0002"],
    title="Exp 3 TD: heatmap encoder, test letters",
    xlim=(1, 600000),
    ylim=(0, 103.5),
)


# ============================================================
# Summary
# ============================================================

print("\n========== Summary ==========")

for key, res in all_results.items():
    print("\n", key)
    print("x_range         :", res["x_range"])
    print("scene_exact_acc :", np.round(res["scene_exact_acc"], 4))
    print("exact_acc       :", np.round(res["exact_acc"], 4))
    print("bit_acc         :", np.round(res["bit_acc"], 4))
    print("n_eval          :", res["n_eval"])
# Out:
# Loaded encoder: ./runs/model_latest_heatmap.pt
# checkpoint epoch: 77
# checkpoint global_step: 36000
#
# ========== Prepare Exp 3 train-letter pool ==========
# Loaded scene cache: ./td_heatmap_encoder_results/exp3_train_letters_scenes_n500000_seed333.npz
# done=500000/500000
# Loading encoded vectors: ./td_heatmap_encoder_results/exp3_train_letters_gt_full_n500000_seed333.npy
# Loading encoded vectors: ./td_heatmap_encoder_results/exp3_train_letters_det_full_n500000_seed333.npy
#
# ========== Prepare Exp 3 test-letter pool ==========
# Loaded scene cache: ./td_heatmap_encoder_results/exp3_test_letters_scenes_n500000_seed444.npz
# done=500000/500000
# Loading encoded vectors: ./td_heatmap_encoder_results/exp3_test_letters_gt_full_n500000_seed444.npy
# Loading encoded vectors: ./td_heatmap_encoder_results/exp3_test_letters_det_full_n500000_seed444.npy
#
# ========== Exp 3 TD: train letters only ==========
# Starting new memory run: ./td_heatmap_encoder_results/centerCNN_exp3_TD_heatmap_encoder_train_letters_npost10000_p0.0005_thr7_seed10.npz
# training centerCNN_exp3_TD_heatmap_encoder_train_letters, N=10000, p=0.0005:   0%|          | 0/500000 [00:00<…
# centerCNN_exp3_TD_heatmap_encoder_train_letters, N=10000, p=0.0005, samples=1, bit_acc=1.0000, exact_acc=1.0000, scene_exact_acc=1.0000, scene_tol_acc=1.0000, n_eval=1
# Saved memory checkpoint: ./td_heatmap_encoder_results/centerCNN_exp3_TD_heatmap_encoder_train_letters_npost10000_p0.0005_thr7_seed10.npz
# centerCNN_exp3_TD_heatmap_encoder_train_letters, N=10000, p=0.0005, samples=10, bit_acc=1.0000, exact_acc=1.0000, scene_exact_acc=1.0000, scene_tol_acc=1.0000, n_eval=10
# Saved memory checkpoint: ./td_heatmap_encoder_results/centerCNN_exp3_TD_heatmap_encoder_train_letters_npost10000_p0.0005_thr7_seed10.npz
# centerCNN_exp3_TD_heatmap_encoder_train_letters, N=10000, p=0.0005, samples=100, bit_acc=0.9999, exact_acc=0.9700, scene_exact_acc=0.9700, scene_tol_acc=1.0000, n_eval=100
# Saved memory checkpoint: ./td_heatmap_encoder_results/centerCNN_exp3_TD_heatmap_encoder_train_letters_npost10000_p0.0005_thr7_seed10.npz
# centerCNN_exp3_TD_heatmap_encoder_train_letters, N=10000, p=0.0005, samples=1000, bit_acc=0.9991, exact_acc=0.9300, scene_exact_acc=0.9300, scene_tol_acc=0.9620, n_eval=1000
# Saved memory checkpoint: ./td_heatmap_encoder_results/centerCNN_exp3_TD_heatmap_encoder_train_letters_npost10000_p0.0005_thr7_seed10.npz
# centerCNN_exp3_TD_heatmap_encoder_train_letters, N=10000, p=0.0005, samples=2000, bit_acc=0.9976, exact_acc=0.8540, scene_exact_acc=0.8540, scene_tol_acc=0.8845, n_eval=2000
# Saved memory checkpoint: ./td_heatmap_encoder_results/centerCNN_exp3_TD_heatmap_encoder_train_letters_npost10000_p0.0005_thr7_seed10.npz
# centerCNN_exp3_TD_heatmap_encoder_train_letters, N=10000, p=0.0005, samples=5000, bit_acc=0.9928, exact_acc=0.5532, scene_exact_acc=0.5532, scene_tol_acc=0.5914, n_eval=5000
# Saved memory checkpoint: ./td_heatmap_encoder_results/centerCNN_exp3_TD_heatmap_encoder_train_letters_npost10000_p0.0005_thr7_seed10.npz
# centerCNN_exp3_TD_heatmap_encoder_train_letters, N=10000, p=0.0005, samples=10000, bit_acc=0.9856, exact_acc=0.1323, scene_exact_acc=0.1323, scene_tol_acc=0.1618, n_eval=10000
# Saved memory checkpoint: ./td_heatmap_encoder_results/centerCNN_exp3_TD_heatmap_encoder_train_letters_npost10000_p0.0005_thr7_seed10.npz
# centerCNN_exp3_TD_heatmap_encoder_train_letters, N=10000, p=0.0005, samples=20000, bit_acc=0.9844, exact_acc=0.0078, scene_exact_acc=0.0078, scene_tol_acc=0.0109, n_eval=10000
# Saved memory checkpoint: ./td_heatmap_encoder_results/centerCNN_exp3_TD_heatmap_encoder_train_letters_npost10000_p0.0005_thr7_seed10.npz
# centerCNN_exp3_TD_heatmap_encoder_train_letters, N=10000, p=0.0005, samples=50000, bit_acc=0.9839, exact_acc=0.0000, scene_exact_acc=0.0000, scene_tol_acc=0.0001, n_eval=10000
# Saved memory checkpoint: ./td_heatmap_encoder_results/centerCNN_exp3_TD_heatmap_encoder_train_letters_npost10000_p0.0005_thr7_seed10.npz
# centerCNN_exp3_TD_heatmap_encoder_train_letters, N=10000, p=0.0005, samples=100000, bit_acc=0.9823, exact_acc=0.0000, scene_exact_acc=0.0000, scene_tol_acc=0.0000, n_eval=10000
# Saved memory checkpoint: ./td_heatmap_encoder_results/centerCNN_exp3_TD_heatmap_encoder_train_letters_npost10000_p0.0005_thr7_seed10.npz
# centerCNN_exp3_TD_heatmap_encoder_train_letters, N=10000, p=0.0005, samples=200000, bit_acc=0.9733, exact_acc=0.0000, scene_exact_acc=0.0000, scene_tol_acc=0.0000, n_eval=10000
# Saved memory checkpoint: ./td_heatmap_encoder_results/centerCNN_exp3_TD_heatmap_encoder_train_letters_npost10000_p0.0005_thr7_seed10.npz
# centerCNN_exp3_TD_heatmap_encoder_train_letters, N=10000, p=0.0005, samples=500000, bit_acc=0.9679, exact_acc=0.0000, scene_exact_acc=0.0000, scene_tol_acc=0.0000, n_eval=10000
# Saved memory checkpoint: ./td_heatmap_encoder_results/centerCNN_exp3_TD_heatmap_encoder_train_letters_npost10000_p0.0005_thr7_seed10.npz
# Saved final memory results: ./td_heatmap_encoder_results/centerCNN_exp3_TD_heatmap_encoder_train_letters_npost10000_p0.0005_thr7_seed10_final.npy
# Starting new memory run: ./td_heatmap_encoder_results/centerCNN_exp3_TD_heatmap_encoder_train_letters_npost50000_p0.0002_thr7_seed10.npz
# training centerCNN_exp3_TD_heatmap_encoder_train_letters, N=50000, p=0.0002:   0%|          | 0/500000 [00:00<…
# centerCNN_exp3_TD_heatmap_encoder_train_letters, N=50000, p=0.0002, samples=1, bit_acc=1.0000, exact_acc=1.0000, scene_exact_acc=1.0000, scene_tol_acc=1.0000, n_eval=1
# Saved memory checkpoint: ./td_heatmap_encoder_results/centerCNN_exp3_TD_heatmap_encoder_train_letters_npost50000_p0.0002_thr7_seed10.npz
# centerCNN_exp3_TD_heatmap_encoder_train_letters, N=50000, p=0.0002, samples=10, bit_acc=1.0000, exact_acc=1.0000, scene_exact_acc=1.0000, scene_tol_acc=1.0000, n_eval=10
# Saved memory checkpoint: ./td_heatmap_encoder_results/centerCNN_exp3_TD_heatmap_encoder_train_letters_npost50000_p0.0002_thr7_seed10.npz
# centerCNN_exp3_TD_heatmap_encoder_train_letters, N=50000, p=0.0002, samples=100, bit_acc=0.9999, exact_acc=0.9700, scene_exact_acc=0.9700, scene_tol_acc=1.0000, n_eval=100
# Saved memory checkpoint: ./td_heatmap_encoder_results/centerCNN_exp3_TD_heatmap_encoder_train_letters_npost50000_p0.0002_thr7_seed10.npz
# centerCNN_exp3_TD_heatmap_encoder_train_letters, N=50000, p=0.0002, samples=1000, bit_acc=0.9998, exact_acc=0.9580, scene_exact_acc=0.9580, scene_tol_acc=0.9900, n_eval=1000
# Saved memory checkpoint: ./td_heatmap_encoder_results/centerCNN_exp3_TD_heatmap_encoder_train_letters_npost50000_p0.0002_thr7_seed10.npz
# centerCNN_exp3_TD_heatmap_encoder_train_letters, N=50000, p=0.0002, samples=2000, bit_acc=0.9998, exact_acc=0.9610, scene_exact_acc=0.9610, scene_tol_acc=0.9895, n_eval=2000
# Saved memory checkpoint: ./td_heatmap_encoder_results/centerCNN_exp3_TD_heatmap_encoder_train_letters_npost50000_p0.0002_thr7_seed10.npz
# centerCNN_exp3_TD_heatmap_encoder_train_letters, N=50000, p=0.0002, samples=5000, bit_acc=0.9997, exact_acc=0.9562, scene_exact_acc=0.9562, scene_tol_acc=0.9814, n_eval=5000
# Saved memory checkpoint: ./td_heatmap_encoder_results/centerCNN_exp3_TD_heatmap_encoder_train_letters_npost50000_p0.0002_thr7_seed10.npz
# centerCNN_exp3_TD_heatmap_encoder_train_letters, N=50000, p=0.0002, samples=10000, bit_acc=0.9991, exact_acc=0.8831, scene_exact_acc=0.8831, scene_tol_acc=0.9155, n_eval=10000
# Saved memory checkpoint: ./td_heatmap_encoder_results/centerCNN_exp3_TD_heatmap_encoder_train_letters_npost50000_p0.0002_thr7_seed10.npz
# centerCNN_exp3_TD_heatmap_encoder_train_letters, N=50000, p=0.0002, samples=20000, bit_acc=0.9964, exact_acc=0.4923, scene_exact_acc=0.4923, scene_tol_acc=0.5484, n_eval=10000
# Saved memory checkpoint: ./td_heatmap_encoder_results/centerCNN_exp3_TD_heatmap_encoder_train_letters_npost50000_p0.0002_thr7_seed10.npz
# centerCNN_exp3_TD_heatmap_encoder_train_letters, N=50000, p=0.0002, samples=50000, bit_acc=0.9893, exact_acc=0.0052, scene_exact_acc=0.0052, scene_tol_acc=0.0090, n_eval=10000
# Saved memory checkpoint: ./td_heatmap_encoder_results/centerCNN_exp3_TD_heatmap_encoder_train_letters_npost50000_p0.0002_thr7_seed10.npz
# centerCNN_exp3_TD_heatmap_encoder_train_letters, N=50000, p=0.0002, samples=100000, bit_acc=0.9852, exact_acc=0.0000, scene_exact_acc=0.0000, scene_tol_acc=0.0001, n_eval=10000
# Saved memory checkpoint: ./td_heatmap_encoder_results/centerCNN_exp3_TD_heatmap_encoder_train_letters_npost50000_p0.0002_thr7_seed10.npz
# centerCNN_exp3_TD_heatmap_encoder_train_letters, N=50000, p=0.0002, samples=200000, bit_acc=0.9830, exact_acc=0.0000, scene_exact_acc=0.0000, scene_tol_acc=0.0000, n_eval=10000
# Saved memory checkpoint: ./td_heatmap_encoder_results/centerCNN_exp3_TD_heatmap_encoder_train_letters_npost50000_p0.0002_thr7_seed10.npz
# centerCNN_exp3_TD_heatmap_encoder_train_letters, N=50000, p=0.0002, samples=500000, bit_acc=0.9808, exact_acc=0.0000, scene_exact_acc=0.0000, scene_tol_acc=0.0000, n_eval=10000
# Saved memory checkpoint: ./td_heatmap_encoder_results/centerCNN_exp3_TD_heatmap_encoder_train_letters_npost50000_p0.0002_thr7_seed10.npz
# Saved final memory results: ./td_heatmap_encoder_results/centerCNN_exp3_TD_heatmap_encoder_train_letters_npost50000_p0.0002_thr7_seed10_final.npy
#
# ========== Exp 3 TD: test letters only ==========
# Starting new memory run: ./td_heatmap_encoder_results/centerCNN_exp3_TD_heatmap_encoder_test_letters_npost10000_p0.0005_thr7_seed10.npz
# training centerCNN_exp3_TD_heatmap_encoder_test_letters, N=10000, p=0.0005:   0%|          | 0/500000 [00:00<?…
# centerCNN_exp3_TD_heatmap_encoder_test_letters, N=10000, p=0.0005, samples=1, bit_acc=1.0000, exact_acc=1.0000, scene_exact_acc=1.0000, scene_tol_acc=1.0000, n_eval=1
# Saved memory checkpoint: ./td_heatmap_encoder_results/centerCNN_exp3_TD_heatmap_encoder_test_letters_npost10000_p0.0005_thr7_seed10.npz
# centerCNN_exp3_TD_heatmap_encoder_test_letters, N=10000, p=0.0005, samples=10, bit_acc=0.9974, exact_acc=0.7000, scene_exact_acc=0.7000, scene_tol_acc=0.8000, n_eval=10
# Saved memory checkpoint: ./td_heatmap_encoder_results/centerCNN_exp3_TD_heatmap_encoder_test_letters_npost10000_p0.0005_thr7_seed10.npz
# centerCNN_exp3_TD_heatmap_encoder_test_letters, N=10000, p=0.0005, samples=100, bit_acc=0.9985, exact_acc=0.7500, scene_exact_acc=0.7500, scene_tol_acc=0.8300, n_eval=100
# Saved memory checkpoint: ./td_heatmap_encoder_results/centerCNN_exp3_TD_heatmap_encoder_test_letters_npost10000_p0.0005_thr7_seed10.npz
# centerCNN_exp3_TD_heatmap_encoder_test_letters, N=10000, p=0.0005, samples=1000, bit_acc=0.9980, exact_acc=0.7500, scene_exact_acc=0.7500, scene_tol_acc=0.8090, n_eval=1000
# Saved memory checkpoint: ./td_heatmap_encoder_results/centerCNN_exp3_TD_heatmap_encoder_test_letters_npost10000_p0.0005_thr7_seed10.npz
# centerCNN_exp3_TD_heatmap_encoder_test_letters, N=10000, p=0.0005, samples=2000, bit_acc=0.9967, exact_acc=0.6890, scene_exact_acc=0.6890, scene_tol_acc=0.7550, n_eval=2000
# Saved memory checkpoint: ./td_heatmap_encoder_results/centerCNN_exp3_TD_heatmap_encoder_test_letters_npost10000_p0.0005_thr7_seed10.npz
# centerCNN_exp3_TD_heatmap_encoder_test_letters, N=10000, p=0.0005, samples=5000, bit_acc=0.9919, exact_acc=0.4406, scene_exact_acc=0.4406, scene_tol_acc=0.5012, n_eval=5000
# Saved memory checkpoint: ./td_heatmap_encoder_results/centerCNN_exp3_TD_heatmap_encoder_test_letters_npost10000_p0.0005_thr7_seed10.npz
# centerCNN_exp3_TD_heatmap_encoder_test_letters, N=10000, p=0.0005, samples=10000, bit_acc=0.9852, exact_acc=0.1118, scene_exact_acc=0.1118, scene_tol_acc=0.1446, n_eval=10000
# Saved memory checkpoint: ./td_heatmap_encoder_results/centerCNN_exp3_TD_heatmap_encoder_test_letters_npost10000_p0.0005_thr7_seed10.npz
# centerCNN_exp3_TD_heatmap_encoder_test_letters, N=10000, p=0.0005, samples=20000, bit_acc=0.9837, exact_acc=0.0059, scene_exact_acc=0.0059, scene_tol_acc=0.0093, n_eval=10000
# Saved memory checkpoint: ./td_heatmap_encoder_results/centerCNN_exp3_TD_heatmap_encoder_test_letters_npost10000_p0.0005_thr7_seed10.npz
# centerCNN_exp3_TD_heatmap_encoder_test_letters, N=10000, p=0.0005, samples=50000, bit_acc=0.9832, exact_acc=0.0000, scene_exact_acc=0.0000, scene_tol_acc=0.0001, n_eval=10000
# Saved memory checkpoint: ./td_heatmap_encoder_results/centerCNN_exp3_TD_heatmap_encoder_test_letters_npost10000_p0.0005_thr7_seed10.npz
# centerCNN_exp3_TD_heatmap_encoder_test_letters, N=10000, p=0.0005, samples=100000, bit_acc=0.9817, exact_acc=0.0000, scene_exact_acc=0.0000, scene_tol_acc=0.0000, n_eval=10000
# Saved memory checkpoint: ./td_heatmap_encoder_results/centerCNN_exp3_TD_heatmap_encoder_test_letters_npost10000_p0.0005_thr7_seed10.npz
# centerCNN_exp3_TD_heatmap_encoder_test_letters, N=10000, p=0.0005, samples=200000, bit_acc=0.9731, exact_acc=0.0000, scene_exact_acc=0.0000, scene_tol_acc=0.0000, n_eval=10000
# Saved memory checkpoint: ./td_heatmap_encoder_results/centerCNN_exp3_TD_heatmap_encoder_test_letters_npost10000_p0.0005_thr7_seed10.npz
# centerCNN_exp3_TD_heatmap_encoder_test_letters, N=10000, p=0.0005, samples=500000, bit_acc=0.9679, exact_acc=0.0000, scene_exact_acc=0.0000, scene_tol_acc=0.0000, n_eval=10000
# Saved memory checkpoint: ./td_heatmap_encoder_results/centerCNN_exp3_TD_heatmap_encoder_test_letters_npost10000_p0.0005_thr7_seed10.npz
# Saved final memory results: ./td_heatmap_encoder_results/centerCNN_exp3_TD_heatmap_encoder_test_letters_npost10000_p0.0005_thr7_seed10_final.npy
# Starting new memory run: ./td_heatmap_encoder_results/centerCNN_exp3_TD_heatmap_encoder_test_letters_npost50000_p0.0002_thr7_seed10.npz
# training centerCNN_exp3_TD_heatmap_encoder_test_letters, N=50000, p=0.0002:   0%|          | 0/500000 [00:00<?…
# centerCNN_exp3_TD_heatmap_encoder_test_letters, N=50000, p=0.0002, samples=1, bit_acc=1.0000, exact_acc=1.0000, scene_exact_acc=1.0000, scene_tol_acc=1.0000, n_eval=1
# Saved memory checkpoint: ./td_heatmap_encoder_results/centerCNN_exp3_TD_heatmap_encoder_test_letters_npost50000_p0.0002_thr7_seed10.npz
# centerCNN_exp3_TD_heatmap_encoder_test_letters, N=50000, p=0.0002, samples=10, bit_acc=0.9974, exact_acc=0.7000, scene_exact_acc=0.7000, scene_tol_acc=0.8000, n_eval=10
# Saved memory checkpoint: ./td_heatmap_encoder_results/centerCNN_exp3_TD_heatmap_encoder_test_letters_npost50000_p0.0002_thr7_seed10.npz
# centerCNN_exp3_TD_heatmap_encoder_test_letters, N=50000, p=0.0002, samples=100, bit_acc=0.9985, exact_acc=0.7500, scene_exact_acc=0.7500, scene_tol_acc=0.8300, n_eval=100
# Saved memory checkpoint: ./td_heatmap_encoder_results/centerCNN_exp3_TD_heatmap_encoder_test_letters_npost50000_p0.0002_thr7_seed10.npz
# centerCNN_exp3_TD_heatmap_encoder_test_letters, N=50000, p=0.0002, samples=1000, bit_acc=0.9988, exact_acc=0.7750, scene_exact_acc=0.7750, scene_tol_acc=0.8350, n_eval=1000
# Saved memory checkpoint: ./td_heatmap_encoder_results/centerCNN_exp3_TD_heatmap_encoder_test_letters_npost50000_p0.0002_thr7_seed10.npz
# centerCNN_exp3_TD_heatmap_encoder_test_letters, N=50000, p=0.0002, samples=2000, bit_acc=0.9988, exact_acc=0.7740, scene_exact_acc=0.7740, scene_tol_acc=0.8400, n_eval=2000
# Saved memory checkpoint: ./td_heatmap_encoder_results/centerCNN_exp3_TD_heatmap_encoder_test_letters_npost50000_p0.0002_thr7_seed10.npz
# centerCNN_exp3_TD_heatmap_encoder_test_letters, N=50000, p=0.0002, samples=5000, bit_acc=0.9987, exact_acc=0.7722, scene_exact_acc=0.7722, scene_tol_acc=0.8412, n_eval=5000
# Saved memory checkpoint: ./td_heatmap_encoder_results/centerCNN_exp3_TD_heatmap_encoder_test_letters_npost50000_p0.0002_thr7_seed10.npz
# centerCNN_exp3_TD_heatmap_encoder_test_letters, N=50000, p=0.0002, samples=10000, bit_acc=0.9981, exact_acc=0.7107, scene_exact_acc=0.7107, scene_tol_acc=0.7787, n_eval=10000
# Saved memory checkpoint: ./td_heatmap_encoder_results/centerCNN_exp3_TD_heatmap_encoder_test_letters_npost50000_p0.0002_thr7_seed10.npz
# centerCNN_exp3_TD_heatmap_encoder_test_letters, N=50000, p=0.0002, samples=20000, bit_acc=0.9954, exact_acc=0.3859, scene_exact_acc=0.3859, scene_tol_acc=0.4568, n_eval=10000
# Saved memory checkpoint: ./td_heatmap_encoder_results/centerCNN_exp3_TD_heatmap_encoder_test_letters_npost50000_p0.0002_thr7_seed10.npz
# centerCNN_exp3_TD_heatmap_encoder_test_letters, N=50000, p=0.0002, samples=50000, bit_acc=0.9885, exact_acc=0.0045, scene_exact_acc=0.0045, scene_tol_acc=0.0077, n_eval=10000
# Saved memory checkpoint: ./td_heatmap_encoder_results/centerCNN_exp3_TD_heatmap_encoder_test_letters_npost50000_p0.0002_thr7_seed10.npz
# centerCNN_exp3_TD_heatmap_encoder_test_letters, N=50000, p=0.0002, samples=100000, bit_acc=0.9844, exact_acc=0.0000, scene_exact_acc=0.0000, scene_tol_acc=0.0000, n_eval=10000
# Saved memory checkpoint: ./td_heatmap_encoder_results/centerCNN_exp3_TD_heatmap_encoder_test_letters_npost50000_p0.0002_thr7_seed10.npz
# centerCNN_exp3_TD_heatmap_encoder_test_letters, N=50000, p=0.0002, samples=200000, bit_acc=0.9826, exact_acc=0.0000, scene_exact_acc=0.0000, scene_tol_acc=0.0000, n_eval=10000
# Saved memory checkpoint: ./td_heatmap_encoder_results/centerCNN_exp3_TD_heatmap_encoder_test_letters_npost50000_p0.0002_thr7_seed10.npz
# centerCNN_exp3_TD_heatmap_encoder_test_letters, N=50000, p=0.0002, samples=500000, bit_acc=0.9800, exact_acc=0.0000, scene_exact_acc=0.0000, scene_tol_acc=0.0000, n_eval=10000
# Saved memory checkpoint: ./td_heatmap_encoder_results/centerCNN_exp3_TD_heatmap_encoder_test_letters_npost50000_p0.0002_thr7_seed10.npz
# Saved final memory results: ./td_heatmap_encoder_results/centerCNN_exp3_TD_heatmap_encoder_test_letters_npost50000_p0.0002_thr7_seed10_final.npy
# Saved all results: ./td_heatmap_encoder_results/all_exp3_td_heatmap_encoder_results.npy
# ========== Summary ==========
#
#  train_exp3_10000_0.0005
# x_range         : [     1     10    100   1000   2000   5000  10000  20000  50000 100000
#  200000 500000]
# scene_exact_acc : [1.     1.     0.97   0.93   0.854  0.5532 0.1323 0.0078 0.     0.
#  0.     0.    ]
# exact_acc       : [1.     1.     0.97   0.93   0.854  0.5532 0.1323 0.0078 0.     0.
#  0.     0.    ]
# bit_acc         : [1.     1.     0.9999 0.9991 0.9976 0.9928 0.9856 0.9844 0.9839 0.9823
#  0.9733 0.9679]
# n_eval          : [    1    10   100  1000  2000  5000 10000 10000 10000 10000 10000 10000]
#
#  train_exp3_50000_0.0002
# x_range         : [     1     10    100   1000   2000   5000  10000  20000  50000 100000
#  200000 500000]
# scene_exact_acc : [1.     1.     0.97   0.958  0.961  0.9562 0.8831 0.4923 0.0052 0.
#  0.     0.    ]
# exact_acc       : [1.     1.     0.97   0.958  0.961  0.9562 0.8831 0.4923 0.0052 0.
#  0.     0.    ]
# bit_acc         : [1.     1.     0.9999 0.9998 0.9998 0.9997 0.9991 0.9964 0.9893 0.9852
#  0.983  0.9808]
# n_eval          : [    1    10   100  1000  2000  5000 10000 10000 10000 10000 10000 10000]
#
#  test_exp3_10000_0.0005
# x_range         : [     1     10    100   1000   2000   5000  10000  20000  50000 100000
#  200000 500000]
# scene_exact_acc : [1.     0.7    0.75   0.75   0.689  0.4406 0.1118 0.0059 0.     0.
#  0.     0.    ]
# exact_acc       : [1.     0.7    0.75   0.75   0.689  0.4406 0.1118 0.0059 0.     0.
#  0.     0.    ]
# bit_acc         : [1.     0.9974 0.9985 0.998  0.9967 0.9919 0.9852 0.9837 0.9832 0.9817
#  0.9731 0.9679]
# n_eval          : [    1    10   100  1000  2000  5000 10000 10000 10000 10000 10000 10000]
#
#  test_exp3_50000_0.0002
# x_range         : [     1     10    100   1000   2000   5000  10000  20000  50000 100000
#  200000 500000]
# scene_exact_acc : [1.     0.7    0.75   0.775  0.774  0.7722 0.7107 0.3859 0.0045 0.
#  0.     0.    ]
# exact_acc       : [1.     0.7    0.75   0.775  0.774  0.7722 0.7107 0.3859 0.0045 0.
#  0.     0.    ]
# bit_acc         : [1.     0.9974 0.9985 0.9988 0.9988 0.9987 0.9981 0.9954 0.9885 0.9844
#  0.9826 0.98  ]
# n_eval          : [    1    10   100  1000  2000  5000 10000 10000 10000 10000 10000 10000]

# %%
# ============================================================
# Exp 3 TD unbinding with trained heatmap model as visual encoder
# Randomized slot version
#
# Scene code:
#   one letter = one-hot(label) + one-hot(x) + one-hot(y)
#   3 letters  = concatenation of 3 letter codes
#   total active bits = 9
#
# This code assumes the CenterHeatmapDetector code above is already defined.
# It uses:
#   ./runs/model_latest_heatmap.pt
# ============================================================

import os
import json
import numpy as np
import torch
import matplotlib.pyplot as plt

from itertools import permutations
from tqdm.notebook import tqdm
from torch.utils.data import DataLoader


# ============================================================
# Config
# ============================================================

TD_CACHE_DIR = "./td_heatmap_encoder_results_randomslots"
os.makedirs(TD_CACHE_DIR, exist_ok=True)

MODEL_PATH = "./runs/model_latest_heatmap.pt"

canvas_size = 64
object_size = 28
k = 3
emnist_split = "letters"

N_LETTERS = 26
IMG_SIZE = canvas_size

INPUT_SIZE = N_LETTERS + IMG_SIZE + IMG_SIZE
FULL_SIZE = INPUT_SIZE * 3

X_RANGE_EXP3 = [
    1, 10, 100, 1000, 2000, 5000, 10000,
    20000, 50000, 100000, 200000, 500000
]

HP_SETS = [
    {
        "n_post": 10000,
        "p": 0.0005,
        "label": "N=10,000, fq=0.05%",
        "color": "tab:blue",
    },
    {
        "n_post": 50000,
        "p": 0.0002,
        "label": "N=50,000, fq=0.02%",
        "color": "tab:orange",
    },
]

EVAL_MAX_ITEMS_EXP3 = 10000
threshold_exp3 = 7

batch_size_encoder = 512
max_exp3 = max(X_RANGE_EXP3)

RANDOMIZE_SLOTS = True


# ============================================================
# Safe cache helpers
# ============================================================

def save_npz_safe(path, **kwargs):
    tmp_path = path + ".tmp.npz"
    np.savez_compressed(tmp_path, **kwargs)

    if os.path.exists(path):
        os.remove(path)

    os.rename(tmp_path, path)


def load_npz_dict(path):
    data = np.load(path, allow_pickle=True)
    return {k: data[k] for k in data.files}


def save_json(path, obj):
    tmp_path = path + ".tmp"

    with open(tmp_path, "w") as f:
        json.dump(obj, f, indent=2)

    if os.path.exists(path):
        os.remove(path)

    os.rename(tmp_path, path)


# ============================================================
# Load trained heatmap model
# ============================================================

def load_heatmap_encoder(model_path=MODEL_PATH, device=None):
    if device is None:
        device = "cuda" if torch.cuda.is_available() else "cpu"

    ckpt = torch.load(model_path, map_location=device)

    model = CenterHeatmapDetector(
        num_classes=ckpt.get("num_classes", 26),
        base_ch=64,
        canvas_size=ckpt.get("canvas_size", 64),
        object_size=ckpt.get("object_size", 28),
    ).to(device)

    if "model_state_dict" in ckpt:
        state = ckpt["model_state_dict"]
    else:
        state = ckpt["model"]

    model.load_state_dict(state)
    model.eval()

    print("Loaded encoder:", model_path)
    print("checkpoint epoch:", ckpt.get("epoch", None))
    print("checkpoint global_step:", ckpt.get("global_step", None))

    return model, ckpt, device


model_encoder, model_ckpt, device = load_heatmap_encoder(MODEL_PATH)


# ============================================================
# Encoding without color
# ============================================================

def encode_letter_no_color(letter_idx, x, y):
    vec = np.zeros(INPUT_SIZE, dtype=np.uint8)

    if letter_idx is not None:
        vec[int(letter_idx)] = 1

    if x is not None:
        vec[N_LETTERS + int(x)] = 1

    if y is not None:
        vec[N_LETTERS + IMG_SIZE + int(y)] = 1

    return vec


def canonicalize_scene_labelxy(scene):
    scene = [tuple(map(int, row)) for row in scene]
    return sorted(scene, key=lambda z: (z[1], z[2], z[0]))


def keep_scene_order_labelxy(scene):
    return [tuple(map(int, row)) for row in scene]


def encode_full_scene_no_color(scene):
    scene = keep_scene_order_labelxy(scene)

    return np.concatenate([
        encode_letter_no_color(letter_idx, x, y)
        for letter_idx, x, y in scene
    ]).astype(np.uint8)


def scenes_to_full_vectors_no_color_cached(scenes, cache_path, desc="encoding scenes"):
    if os.path.exists(cache_path):
        print("Loading encoded vectors:", cache_path)
        return np.load(cache_path)

    arr = np.zeros((len(scenes), FULL_SIZE), dtype=np.uint8)

    for i in tqdm(range(len(scenes)), desc=desc):
        arr[i] = encode_full_scene_no_color(scenes[i])

    np.save(cache_path, arr)
    print("Saved encoded vectors:", cache_path)

    return arr


def wta_decode_full_no_color(reconstruct):
    decoded = np.zeros(FULL_SIZE, dtype=np.uint8)

    for part in range(3):
        base = part * INPUT_SIZE

        i = np.argmax(reconstruct[base : base + N_LETTERS])
        decoded[base + i] = 1

        offset = base + N_LETTERS
        i = np.argmax(reconstruct[offset : offset + IMG_SIZE])
        decoded[offset + i] = 1

        offset += IMG_SIZE
        i = np.argmax(reconstruct[offset : offset + IMG_SIZE])
        decoded[offset + i] = 1

    return decoded


def full_vector_to_scene_no_color(vec):
    scene = []

    for part in range(3):
        base = part * INPUT_SIZE

        letter_idx = int(np.argmax(vec[base : base + N_LETTERS]))

        offset = base + N_LETTERS
        x = int(np.argmax(vec[offset : offset + IMG_SIZE]))

        offset += IMG_SIZE
        y = int(np.argmax(vec[offset : offset + IMG_SIZE]))

        scene.append((letter_idx, x, y))

    return canonicalize_scene_labelxy(scene)


def scene_match_tolerant_labelxy(pred_scene, target_scene, xy_tol=1):
    pred_scene = [tuple(map(int, row)) for row in pred_scene]
    target_scene = [tuple(map(int, row)) for row in target_scene]

    K = len(pred_scene)

    for p in permutations(range(K)):
        ok = True

        for i in range(K):
            lp, xp, yp = pred_scene[i]
            lt, xt, yt = target_scene[p[i]]

            if lp != lt:
                ok = False
                break

            if abs(xp - xt) > xy_tol:
                ok = False
                break

            if abs(yp - yt) > xy_tol:
                ok = False
                break

        if ok:
            return True

    return False


# ============================================================
# Slot randomization
# ============================================================

def randomize_slot_order_pair_labelxy(gt_scene, det_scene, rng):
    gt_aligned = np.asarray(canonicalize_scene_labelxy(gt_scene), dtype=np.int16)
    det_aligned = np.asarray(canonicalize_scene_labelxy(det_scene), dtype=np.int16)

    perm = rng.permutation(3)

    return gt_aligned[perm], det_aligned[perm]


def randomize_slot_order_pool_labelxy(gt_scenes, det_scenes, seed=0):
    rng = np.random.default_rng(seed)

    gt_out = np.zeros_like(gt_scenes, dtype=np.int16)
    det_out = np.zeros_like(det_scenes, dtype=np.int16)

    for i in tqdm(range(len(gt_scenes)), desc="randomizing slot order"):
        gt_out[i], det_out[i] = randomize_slot_order_pair_labelxy(
            gt_scene=gt_scenes[i],
            det_scene=det_scenes[i],
            rng=rng,
        )

    return gt_out, det_out


# ============================================================
# Convert boxes to integer centers
# ============================================================

def boxes_to_integer_centers_numpy(boxes, canvas_size=64):
    cx = np.rint((boxes[..., 0] + boxes[..., 2]) * 0.5 * canvas_size).astype(np.int16)
    cy = np.rint((boxes[..., 1] + boxes[..., 3]) * 0.5 * canvas_size).astype(np.int16)

    cx = np.clip(cx, 0, canvas_size - 1)
    cy = np.clip(cy, 0, canvas_size - 1)

    return cx, cy


@torch.no_grad()
def detect_batch_as_labelxy(model, x, device, k=3, canvas_size=64, object_size=28):
    x = x.to(device, non_blocking=True)

    logits = model(x)

    pred_boxes, pred_labels, pred_scores = decode_heatmap_topk(
        logits=logits,
        k=k,
        canvas_size=canvas_size,
        object_size=object_size,
    )

    pred_boxes = pred_boxes.detach().cpu().numpy()
    pred_labels = pred_labels.detach().cpu().numpy().astype(np.int16)

    pred_cx, pred_cy = boxes_to_integer_centers_numpy(
        pred_boxes,
        canvas_size=canvas_size,
    )

    B = pred_labels.shape[0]
    scenes = np.zeros((B, k, 3), dtype=np.int16)

    for i in range(B):
        objs = []

        for j in range(k):
            objs.append((
                int(pred_labels[i, j]),
                int(pred_cx[i, j]),
                int(pred_cy[i, j]),
            ))

        scenes[i] = np.asarray(
            canonicalize_scene_labelxy(objs),
            dtype=np.int16,
        )

    return scenes


def gt_batch_as_labelxy(gt_boxes, gt_labels, canvas_size=64, k=3):
    gt_boxes = gt_boxes.detach().cpu().numpy()
    gt_labels = gt_labels.detach().cpu().numpy().astype(np.int16)

    gt_cx, gt_cy = boxes_to_integer_centers_numpy(
        gt_boxes,
        canvas_size=canvas_size,
    )

    B = gt_labels.shape[0]
    scenes = np.zeros((B, k, 3), dtype=np.int16)

    for i in range(B):
        objs = []

        for j in range(k):
            objs.append((
                int(gt_labels[i, j]),
                int(gt_cx[i, j]),
                int(gt_cy[i, j]),
            ))

        scenes[i] = np.asarray(
            canonicalize_scene_labelxy(objs),
            dtype=np.int16,
        )

    return scenes


# ============================================================
# Build train-only or test-only visual-encoder pools
# ============================================================

def build_heatmap_encoder_pool_cached(
    split_name,
    train_flag,
    max_images,
    seed,
    model,
    device,
    rebuild=False,
    save_every_batches=20,
    randomize_slots=True,
):
    scene_cache_path = os.path.join(
        TD_CACHE_DIR,
        f"exp3_{split_name}_base_scenes_n{max_images}_seed{seed}.npz"
    )

    slot_seed = seed + 999

    randomized_scene_cache_path = os.path.join(
        TD_CACHE_DIR,
        f"exp3_{split_name}_scenes_n{max_images}_seed{seed}_rand{int(randomize_slots)}_slotseed{slot_seed}.npz"
    )

    det_full_path = os.path.join(
        TD_CACHE_DIR,
        f"exp3_{split_name}_det_full_n{max_images}_seed{seed}_rand{int(randomize_slots)}_slotseed{slot_seed}.npy"
    )

    gt_full_path = os.path.join(
        TD_CACHE_DIR,
        f"exp3_{split_name}_gt_full_n{max_images}_seed{seed}_rand{int(randomize_slots)}_slotseed{slot_seed}.npy"
    )

    if os.path.exists(scene_cache_path) and (not rebuild):
        obj = load_npz_dict(scene_cache_path)

        gt_scenes = obj["gt_scenes"]
        det_scenes = obj["det_scenes"]
        done = int(obj.get("done", max_images))

        print("Loaded base scene cache:", scene_cache_path)
        print(f"done={done}/{max_images}")

        if done < max_images:
            print("Base scene cache is incomplete. Resume encoding.")

    if (not os.path.exists(scene_cache_path)) or rebuild or done < max_images:
        if os.path.exists(scene_cache_path) and (not rebuild):
            obj = load_npz_dict(scene_cache_path)

            gt_scenes = obj["gt_scenes"]
            det_scenes = obj["det_scenes"]
            done = int(obj.get("done", 0))

            print("Resuming base scene encoding from cache:", scene_cache_path)
            print(f"done={done}/{max_images}")

        else:
            gt_scenes = np.zeros((max_images, k, 3), dtype=np.int16)
            det_scenes = np.zeros((max_images, k, 3), dtype=np.int16)
            done = 0

            print("Starting new base scene encoding:", scene_cache_path)

        ds = ThreeCharEMNIST(
            root="./data",
            train=train_flag,
            split=emnist_split,
            canvas_size=canvas_size,
            chars_per_image=k,
            length=max_images,
            seed=seed,
            allow_overlap=False,
            placement_tries=80,
            min_separation=2,
            augment=False,
        )

        loader = DataLoader(
            ds,
            batch_size=batch_size_encoder,
            shuffle=False,
            num_workers=0,
            pin_memory=True,
        )

        model.eval()

        batch_counter = 0
        current_start = 0

        for x, gt_boxes, gt_labels in tqdm(
            loader,
            desc=f"encoding {split_name} with heatmap model",
        ):
            B = x.shape[0]
            current_end = current_start + B

            if current_end <= done:
                current_start = current_end
                continue

            if current_start < done < current_end:
                keep_from = done - current_start

                x = x[keep_from:]
                gt_boxes = gt_boxes[keep_from:]
                gt_labels = gt_labels[keep_from:]

                current_start = done
                B = x.shape[0]
                current_end = current_start + B

            gt_scenes[current_start:current_end] = gt_batch_as_labelxy(
                gt_boxes=gt_boxes,
                gt_labels=gt_labels,
                canvas_size=canvas_size,
                k=k,
            )

            det_scenes[current_start:current_end] = detect_batch_as_labelxy(
                model=model,
                x=x,
                device=device,
                k=k,
                canvas_size=canvas_size,
                object_size=object_size,
            )

            done = current_end
            batch_counter += 1

            if batch_counter % save_every_batches == 0 or done >= max_images:
                save_npz_safe(
                    scene_cache_path,
                    gt_scenes=gt_scenes,
                    det_scenes=det_scenes,
                    done=np.array(done, dtype=np.int64),
                )

                print(f"Saved partial base scene cache: done={done}/{max_images}")

            current_start = current_end

        exact_scene_acc = float(
            np.mean(np.all(det_scenes == gt_scenes, axis=(1, 2)))
        )

        print(f"{split_name} visual encoder exact scene acc: {exact_scene_acc:.4f}")

        save_npz_safe(
            scene_cache_path,
            gt_scenes=gt_scenes,
            det_scenes=det_scenes,
            done=np.array(max_images, dtype=np.int64),
            exact_scene_acc=np.array(exact_scene_acc, dtype=np.float32),
        )

        save_json(
            scene_cache_path.replace(".npz", "_meta.json"),
            {
                "split_name": split_name,
                "train_flag": bool(train_flag),
                "max_images": int(max_images),
                "seed": int(seed),
                "model_path": MODEL_PATH,
                "exact_scene_acc": exact_scene_acc,
                "code": "base canonical scenes before slot randomization",
            },
        )

        print("Saved final base scene cache:", scene_cache_path)

    if os.path.exists(randomized_scene_cache_path) and (not rebuild):
        obj = load_npz_dict(randomized_scene_cache_path)

        gt_scenes_work = obj["gt_scenes"]
        det_scenes_work = obj["det_scenes"]

        print("Loaded working scene cache:", randomized_scene_cache_path)

    else:
        if randomize_slots:
            gt_scenes_work, det_scenes_work = randomize_slot_order_pool_labelxy(
                gt_scenes=gt_scenes,
                det_scenes=det_scenes,
                seed=slot_seed,
            )
        else:
            gt_scenes_work = gt_scenes.copy()
            det_scenes_work = det_scenes.copy()

        save_npz_safe(
            randomized_scene_cache_path,
            gt_scenes=gt_scenes_work,
            det_scenes=det_scenes_work,
            randomize_slots=np.array(int(randomize_slots), dtype=np.int32),
            slot_seed=np.array(slot_seed, dtype=np.int64),
        )

        print("Saved working scene cache:", randomized_scene_cache_path)

    gt_full = scenes_to_full_vectors_no_color_cached(
        gt_scenes_work,
        cache_path=gt_full_path,
        desc=f"encoding {split_name} GT full vectors",
    )

    det_full = scenes_to_full_vectors_no_color_cached(
        det_scenes_work,
        cache_path=det_full_path,
        desc=f"encoding {split_name} visual-encoder full vectors",
    )

    return gt_scenes_work, det_scenes_work, det_full, gt_full


# ============================================================
# Memory model
# ============================================================

def memory_update(W_ff, W_fb, full_input, rng, p):
    selected = rng.random(W_ff.shape[0]) <= p

    if not np.any(selected):
        return

    sel_idx = np.flatnonzero(selected)
    active_idx = np.flatnonzero(full_input)

    if len(active_idx) == 0:
        return

    sub = W_ff[np.ix_(sel_idx, active_idx)]
    set_to_1 = sub == 0

    W_ff[np.ix_(sel_idx, active_idx)] = 1 - sub

    rows, cols = np.where(set_to_1.T)

    if len(rows) > 0:
        W_fb[active_idx[rows], sel_idx[cols]] = 1


def evaluate_memory_td_no_color(
    W_ff,
    W_fb,
    cues,
    targets,
    threshold,
    max_items=None,
    xy_tol=2,
):
    n_total = len(cues)

    if max_items is None or max_items >= n_total:
        eval_idx = np.arange(n_total)
    else:
        eval_idx = np.linspace(0, n_total - 1, max_items).astype(int)

    W_ff_i = W_ff.astype(np.int16, copy=False)
    W_fb_i = W_fb.astype(np.int16, copy=False)

    bit_accs = []
    exacts = []
    scene_exacts = []
    scene_tolerant_exacts = []

    for idx in eval_idx:
        cue = cues[idx].astype(np.int16, copy=False)
        target = targets[idx].astype(np.uint8, copy=False)

        hidden = (W_ff_i @ cue) > threshold
        reconstruct = W_fb_i @ hidden.astype(np.int16)

        decoded = wta_decode_full_no_color(reconstruct)

        bit_accs.append(np.mean(decoded == target))
        exacts.append(float(np.array_equal(decoded, target)))

        decoded_scene = full_vector_to_scene_no_color(decoded)
        target_scene = full_vector_to_scene_no_color(target)

        scene_exacts.append(float(decoded_scene == target_scene))

        tolerant_ok = scene_match_tolerant_labelxy(
            pred_scene=decoded_scene,
            target_scene=target_scene,
            xy_tol=xy_tol,
        )

        scene_tolerant_exacts.append(float(tolerant_ok))

    return {
        "bit_acc": float(np.mean(bit_accs)),
        "exact_acc": float(np.mean(exacts)),
        "scene_exact_acc": float(np.mean(scene_exacts)),
        "scene_tolerant_exact_acc": float(np.mean(scene_tolerant_exacts)),
        "xy_tol": int(xy_tol),
        "n_eval": int(len(eval_idx)),
    }


def run_curve_incremental_checkpointed_td_no_color(
    train_vectors,
    cue_vectors,
    target_vectors,
    x_range,
    n_post,
    p,
    threshold,
    seed=0,
    max_eval_items=None,
    cache_name="experiment",
    cache_dir=TD_CACHE_DIR,
    force_restart=False,
):
    os.makedirs(cache_dir, exist_ok=True)

    ckpt_path = os.path.join(
        cache_dir,
        f"{cache_name}_npost{n_post}_p{p}_thr{threshold}_seed{seed}.npz"
    )

    x_range = list(x_range)
    max_n = max(x_range)
    x_set = set(x_range)

    rng = np.random.default_rng(seed)

    if os.path.exists(ckpt_path) and not force_restart:
        print("Loading memory checkpoint:", ckpt_path)

        ckpt = np.load(ckpt_path, allow_pickle=True)

        W_ff = ckpt["W_ff"]
        W_fb = ckpt["W_fb"]
        start_i = int(ckpt["current_i"])

        results = {
            "x_range": ckpt["x_range"].tolist(),
            "bit_acc": ckpt["bit_acc"].tolist(),
            "exact_acc": ckpt["exact_acc"].tolist(),
            "scene_exact_acc": ckpt["scene_exact_acc"].tolist(),
            "scene_tolerant_exact_acc": ckpt["scene_tolerant_exact_acc"].tolist()
                if "scene_tolerant_exact_acc" in ckpt.files else [],
            "n_eval": ckpt["n_eval"].tolist(),
        }

        rng_state = ckpt["rng_state"].item()
        rng.bit_generator.state = rng_state

        print(f"Resuming from sample {start_i}")
        print("Finished datapoints:", results["x_range"])

    else:
        print("Starting new memory run:", ckpt_path)

        W_ff = np.zeros((n_post, FULL_SIZE), dtype=np.uint8)
        W_fb = np.zeros((FULL_SIZE, n_post), dtype=np.uint8)

        start_i = 0

        results = {
            "x_range": [],
            "bit_acc": [],
            "exact_acc": [],
            "scene_exact_acc": [],
            "scene_tolerant_exact_acc": [],
            "n_eval": [],
        }

    for i in tqdm(range(start_i, max_n), desc=f"training {cache_name}, N={n_post}, p={p}"):
        memory_update(
            W_ff=W_ff,
            W_fb=W_fb,
            full_input=train_vectors[i],
            rng=rng,
            p=p,
        )

        current_n = i + 1

        if current_n in x_set:
            stats = evaluate_memory_td_no_color(
                W_ff=W_ff,
                W_fb=W_fb,
                cues=cue_vectors[:current_n],
                targets=target_vectors[:current_n],
                threshold=threshold,
                max_items=max_eval_items,
                xy_tol=2,
            )

            print(
                f"{cache_name}, N={n_post}, p={p}, samples={current_n}, "
                f"bit_acc={stats['bit_acc']:.4f}, "
                f"exact_acc={stats['exact_acc']:.4f}, "
                f"scene_exact_acc={stats['scene_exact_acc']:.4f}, "
                f"scene_tol_acc={stats['scene_tolerant_exact_acc']:.4f}, "
                f"n_eval={stats['n_eval']}"
            )

            if current_n not in results["x_range"]:
                results["x_range"].append(current_n)
                results["bit_acc"].append(stats["bit_acc"])
                results["exact_acc"].append(stats["exact_acc"])
                results["scene_exact_acc"].append(stats["scene_exact_acc"])
                results["scene_tolerant_exact_acc"].append(stats["scene_tolerant_exact_acc"])
                results["n_eval"].append(stats["n_eval"])

            save_npz_safe(
                ckpt_path,
                W_ff=W_ff,
                W_fb=W_fb,
                current_i=np.array(current_n, dtype=np.int64),
                x_range=np.asarray(results["x_range"]),
                bit_acc=np.asarray(results["bit_acc"]),
                exact_acc=np.asarray(results["exact_acc"]),
                scene_exact_acc=np.asarray(results["scene_exact_acc"]),
                scene_tolerant_exact_acc=np.asarray(results["scene_tolerant_exact_acc"]),
                n_eval=np.asarray(results["n_eval"]),
                rng_state=np.array(rng.bit_generator.state, dtype=object),
            )

            print("Saved memory checkpoint:", ckpt_path)

    final_results = {
        "x_range": np.asarray(results["x_range"]),
        "bit_acc": np.asarray(results["bit_acc"]),
        "exact_acc": np.asarray(results["exact_acc"]),
        "scene_exact_acc": np.asarray(results["scene_exact_acc"]),
        "scene_tolerant_exact_acc": np.asarray(results["scene_tolerant_exact_acc"]),
        "n_eval": np.asarray(results["n_eval"]),
    }

    final_path = os.path.join(
        cache_dir,
        f"{cache_name}_npost{n_post}_p{p}_thr{threshold}_seed{seed}_final.npy"
    )

    np.save(final_path, final_results)

    print("Saved final memory results:", final_path)

    return final_results


# ============================================================
# Plotting
# ============================================================

def plot_td_pair(res_10000, res_50000, title, xlim=(1, 600000), ylim=(0, 103.5)):
    plt.figure(figsize=(4, 3), dpi=300)

    plt.plot(
        res_10000["x_range"],
        res_10000["scene_exact_acc"] * 100,
        marker="o",
        lw=3,
        label="N=10,000, fq=0.05%",
        color="tab:blue",
        alpha=0.85,
    )

    plt.plot(
        res_50000["x_range"],
        res_50000["scene_exact_acc"] * 100,
        marker="o",
        lw=3,
        label="N=50,000, fq=0.02%",
        color="tab:orange",
        alpha=0.85,
    )

    plt.xscale("log")
    plt.xlim(*xlim)
    plt.ylim(*ylim)

    plt.xlabel("Number of stored canvases")
    plt.ylabel("TD unbinding accuracy / %")
    plt.title(title)
    plt.legend()
    plt.tight_layout()
    plt.show()


# ============================================================
# Prepare data
# ============================================================

print("\n========== Prepare Exp 3 train-letter pool ==========")

gt_scenes_train, det_scenes_train, det_full_train, gt_full_train = build_heatmap_encoder_pool_cached(
    split_name="train_letters",
    train_flag=True,
    max_images=max_exp3,
    seed=333,
    model=model_encoder,
    device=device,
    rebuild=False,
    randomize_slots=RANDOMIZE_SLOTS,
)

rng = np.random.default_rng(2)

perm_train = rng.permutation(len(det_full_train))

det_full_train = det_full_train[perm_train]
gt_full_train = gt_full_train[perm_train]

det_scenes_train = det_scenes_train[perm_train]
gt_scenes_train = gt_scenes_train[perm_train]


print("\n========== Prepare Exp 3 test-letter pool ==========")

gt_scenes_test, det_scenes_test, det_full_test, gt_full_test = build_heatmap_encoder_pool_cached(
    split_name="test_letters",
    train_flag=False,
    max_images=max_exp3,
    seed=444,
    model=model_encoder,
    device=device,
    rebuild=False,
    randomize_slots=RANDOMIZE_SLOTS,
)

rng = np.random.default_rng(2)

perm_test = rng.permutation(len(det_full_test))

det_full_test = det_full_test[perm_test]
gt_full_test = gt_full_test[perm_test]

det_scenes_test = det_scenes_test[perm_test]
gt_scenes_test = gt_scenes_test[perm_test]


# ============================================================
# Run train-only Exp 3
# ============================================================

all_results = {}

print("\n========== Exp 3 TD: train letters only, randomized slots ==========")

for hp in HP_SETS:
    res = run_curve_incremental_checkpointed_td_no_color(
        train_vectors=det_full_train,
        cue_vectors=det_full_train,
        target_vectors=gt_full_train,
        x_range=X_RANGE_EXP3,
        n_post=hp["n_post"],
        p=hp["p"],
        threshold=threshold_exp3,
        seed=3000 + hp["n_post"],
        max_eval_items=EVAL_MAX_ITEMS_EXP3,
        cache_name="centerCNN_exp3_TD_heatmap_encoder_train_letters_rand_slots",
        force_restart=False,
    )

    all_results[f"train_exp3_{hp['n_post']}_{hp['p']}"] = res


# ============================================================
# Run test-only Exp 3
# ============================================================

print("\n========== Exp 3 TD: test letters only, randomized slots ==========")

for hp in HP_SETS:
    res = run_curve_incremental_checkpointed_td_no_color(
        train_vectors=det_full_test,
        cue_vectors=det_full_test,
        target_vectors=gt_full_test,
        x_range=X_RANGE_EXP3,
        n_post=hp["n_post"],
        p=hp["p"],
        threshold=threshold_exp3,
        seed=4000 + hp["n_post"],
        max_eval_items=EVAL_MAX_ITEMS_EXP3,
        cache_name="centerCNN_exp3_TD_heatmap_encoder_test_letters_rand_slots",
        force_restart=False,
    )

    all_results[f"test_exp3_{hp['n_post']}_{hp['p']}"] = res


# ============================================================
# Save and plot
# ============================================================

all_results_path = os.path.join(
    TD_CACHE_DIR,
    "all_exp3_td_heatmap_encoder_results_rand_slots.npy"
)

np.save(all_results_path, all_results, allow_pickle=True)

print("Saved all results:", all_results_path)

plot_td_pair(
    res_10000=all_results["train_exp3_10000_0.0005"],
    res_50000=all_results["train_exp3_50000_0.0002"],
    title="Exp 3 TD: heatmap encoder, train letters, randomized slots",
    xlim=(1, 600000),
    ylim=(0, 103.5),
)

plot_td_pair(
    res_10000=all_results["test_exp3_10000_0.0005"],
    res_50000=all_results["test_exp3_50000_0.0002"],
    title="Exp 3 TD: heatmap encoder, test letters, randomized slots",
    xlim=(1, 600000),
    ylim=(0, 103.5),
)


# ============================================================
# Summary
# ============================================================

print("\n========== Summary ==========")

for key, res in all_results.items():
    print("\n", key)
    print("x_range         :", res["x_range"])
    print("scene_exact_acc :", np.round(res["scene_exact_acc"], 4))
    print("exact_acc       :", np.round(res["exact_acc"], 4))
    print("bit_acc         :", np.round(res["bit_acc"], 4))
    print("n_eval          :", res["n_eval"])
# Out:
# Loaded encoder: ./runs/model_latest_heatmap.pt
# checkpoint epoch: 77
# checkpoint global_step: 36000
#
# ========== Prepare Exp 3 train-letter pool ==========
# Starting new base scene encoding: ./td_heatmap_encoder_results_randomslots/exp3_train_letters_base_scenes_n500000_seed333.npz
# encoding train_letters with heatmap model:   0%|          | 0/977 [00:00<?, ?it/s]
# Saved partial base scene cache: done=10240/500000
# Saved partial base scene cache: done=20480/500000
# Saved partial base scene cache: done=30720/500000
# Saved partial base scene cache: done=40960/500000
# Saved partial base scene cache: done=51200/500000
# Saved partial base scene cache: done=61440/500000
# Saved partial base scene cache: done=71680/500000
# Saved partial base scene cache: done=81920/500000
# Saved partial base scene cache: done=92160/500000
# Saved partial base scene cache: done=102400/500000
# Saved partial base scene cache: done=112640/500000
# Saved partial base scene cache: done=122880/500000
# Saved partial base scene cache: done=133120/500000
# Saved partial base scene cache: done=143360/500000
# Saved partial base scene cache: done=153600/500000
# Saved partial base scene cache: done=163840/500000
# Saved partial base scene cache: done=174080/500000
# Saved partial base scene cache: done=184320/500000
# Saved partial base scene cache: done=194560/500000
# Saved partial base scene cache: done=204800/500000
# Saved partial base scene cache: done=215040/500000
# Saved partial base scene cache: done=225280/500000
# Saved partial base scene cache: done=235520/500000
# Saved partial base scene cache: done=245760/500000
# Saved partial base scene cache: done=256000/500000
# Saved partial base scene cache: done=266240/500000
# Saved partial base scene cache: done=276480/500000
# Saved partial base scene cache: done=286720/500000
# Saved partial base scene cache: done=296960/500000
# Saved partial base scene cache: done=307200/500000
# Saved partial base scene cache: done=317440/500000
# Saved partial base scene cache: done=327680/500000
# Saved partial base scene cache: done=337920/500000
# Saved partial base scene cache: done=348160/500000
# Saved partial base scene cache: done=358400/500000
# Saved partial base scene cache: done=368640/500000
# Saved partial base scene cache: done=378880/500000
# Saved partial base scene cache: done=389120/500000
# Saved partial base scene cache: done=399360/500000
# Saved partial base scene cache: done=409600/500000
# Saved partial base scene cache: done=419840/500000
# Saved partial base scene cache: done=430080/500000
# Saved partial base scene cache: done=440320/500000
# Saved partial base scene cache: done=450560/500000
# Saved partial base scene cache: done=460800/500000
# Saved partial base scene cache: done=471040/500000
# Saved partial base scene cache: done=481280/500000
# Saved partial base scene cache: done=491520/500000
# Saved partial base scene cache: done=500000/500000
# train_letters visual encoder exact scene acc: 0.9631
# Saved final base scene cache: ./td_heatmap_encoder_results_randomslots/exp3_train_letters_base_scenes_n500000_seed333.npz
# randomizing slot order:   0%|          | 0/500000 [00:00<?, ?it/s]
# Saved working scene cache: ./td_heatmap_encoder_results_randomslots/exp3_train_letters_scenes_n500000_seed333_rand1_slotseed1332.npz
# encoding train_letters GT full vectors:   0%|          | 0/500000 [00:00<?, ?it/s]
# Saved encoded vectors: ./td_heatmap_encoder_results_randomslots/exp3_train_letters_gt_full_n500000_seed333_rand1_slotseed1332.npy
# encoding train_letters visual-encoder full vectors:   0%|          | 0/500000 [00:00<?, ?it/s]
# Saved encoded vectors: ./td_heatmap_encoder_results_randomslots/exp3_train_letters_det_full_n500000_seed333_rand1_slotseed1332.npy
#
# ========== Prepare Exp 3 test-letter pool ==========
# Starting new base scene encoding: ./td_heatmap_encoder_results_randomslots/exp3_test_letters_base_scenes_n500000_seed444.npz
# encoding test_letters with heatmap model:   0%|          | 0/977 [00:00<?, ?it/s]
# Saved partial base scene cache: done=10240/500000
# Saved partial base scene cache: done=20480/500000
# Saved partial base scene cache: done=30720/500000
# Saved partial base scene cache: done=40960/500000
# Saved partial base scene cache: done=51200/500000
# Saved partial base scene cache: done=61440/500000
# Saved partial base scene cache: done=71680/500000
# Saved partial base scene cache: done=81920/500000
# Saved partial base scene cache: done=92160/500000
# Saved partial base scene cache: done=102400/500000
# Saved partial base scene cache: done=112640/500000
# Saved partial base scene cache: done=122880/500000
# Saved partial base scene cache: done=133120/500000
# Saved partial base scene cache: done=143360/500000
# Saved partial base scene cache: done=153600/500000
# Saved partial base scene cache: done=163840/500000
# Saved partial base scene cache: done=174080/500000
# Saved partial base scene cache: done=184320/500000
# Saved partial base scene cache: done=194560/500000
# Saved partial base scene cache: done=204800/500000
# Saved partial base scene cache: done=215040/500000
# Saved partial base scene cache: done=225280/500000
# Saved partial base scene cache: done=235520/500000
# Saved partial base scene cache: done=245760/500000
# Saved partial base scene cache: done=256000/500000
# Saved partial base scene cache: done=266240/500000
# Saved partial base scene cache: done=276480/500000
# Saved partial base scene cache: done=286720/500000
# Saved partial base scene cache: done=296960/500000
# Saved partial base scene cache: done=307200/500000
# Saved partial base scene cache: done=317440/500000
# Saved partial base scene cache: done=327680/500000
# Saved partial base scene cache: done=337920/500000
# Saved partial base scene cache: done=348160/500000
# Saved partial base scene cache: done=358400/500000
# Saved partial base scene cache: done=368640/500000
# Saved partial base scene cache: done=378880/500000
# Saved partial base scene cache: done=389120/500000
# Saved partial base scene cache: done=399360/500000
# Saved partial base scene cache: done=409600/500000
# Saved partial base scene cache: done=419840/500000
# Saved partial base scene cache: done=430080/500000
# Saved partial base scene cache: done=440320/500000
# Saved partial base scene cache: done=450560/500000
# Saved partial base scene cache: done=460800/500000
# Saved partial base scene cache: done=471040/500000
# Saved partial base scene cache: done=481280/500000
# Saved partial base scene cache: done=491520/500000
# Saved partial base scene cache: done=500000/500000
# test_letters visual encoder exact scene acc: 0.7727
# Saved final base scene cache: ./td_heatmap_encoder_results_randomslots/exp3_test_letters_base_scenes_n500000_seed444.npz
# randomizing slot order:   0%|          | 0/500000 [00:00<?, ?it/s]
# Saved working scene cache: ./td_heatmap_encoder_results_randomslots/exp3_test_letters_scenes_n500000_seed444_rand1_slotseed1443.npz
# encoding test_letters GT full vectors:   0%|          | 0/500000 [00:00<?, ?it/s]
# Saved encoded vectors: ./td_heatmap_encoder_results_randomslots/exp3_test_letters_gt_full_n500000_seed444_rand1_slotseed1443.npy
# encoding test_letters visual-encoder full vectors:   0%|          | 0/500000 [00:00<?, ?it/s]
# Saved encoded vectors: ./td_heatmap_encoder_results_randomslots/exp3_test_letters_det_full_n500000_seed444_rand1_slotseed1443.npy
#
# ========== Exp 3 TD: train letters only, randomized slots ==========
# Starting new memory run: ./td_heatmap_encoder_results_randomslots/centerCNN_exp3_TD_heatmap_encoder_train_letters_rand_slots_npost10000_p0.0005_thr7_seed13000.npz
# training centerCNN_exp3_TD_heatmap_encoder_train_letters_rand_slots, N=10000, p=0.0005:   0%|          | 0/500…
# centerCNN_exp3_TD_heatmap_encoder_train_letters_rand_slots, N=10000, p=0.0005, samples=1, bit_acc=1.0000, exact_acc=1.0000, scene_exact_acc=1.0000, scene_tol_acc=1.0000, n_eval=1
# Saved memory checkpoint: ./td_heatmap_encoder_results_randomslots/centerCNN_exp3_TD_heatmap_encoder_train_letters_rand_slots_npost10000_p0.0005_thr7_seed13000.npz
# centerCNN_exp3_TD_heatmap_encoder_train_letters_rand_slots, N=10000, p=0.0005, samples=10, bit_acc=1.0000, exact_acc=1.0000, scene_exact_acc=1.0000, scene_tol_acc=1.0000, n_eval=10
# Saved memory checkpoint: ./td_heatmap_encoder_results_randomslots/centerCNN_exp3_TD_heatmap_encoder_train_letters_rand_slots_npost10000_p0.0005_thr7_seed13000.npz
# centerCNN_exp3_TD_heatmap_encoder_train_letters_rand_slots, N=10000, p=0.0005, samples=100, bit_acc=0.9999, exact_acc=0.9700, scene_exact_acc=0.9700, scene_tol_acc=1.0000, n_eval=100
# Saved memory checkpoint: ./td_heatmap_encoder_results_randomslots/centerCNN_exp3_TD_heatmap_encoder_train_letters_rand_slots_npost10000_p0.0005_thr7_seed13000.npz
# centerCNN_exp3_TD_heatmap_encoder_train_letters_rand_slots, N=10000, p=0.0005, samples=1000, bit_acc=0.9991, exact_acc=0.9270, scene_exact_acc=0.9270, scene_tol_acc=0.9590, n_eval=1000
# Saved memory checkpoint: ./td_heatmap_encoder_results_randomslots/centerCNN_exp3_TD_heatmap_encoder_train_letters_rand_slots_npost10000_p0.0005_thr7_seed13000.npz
# centerCNN_exp3_TD_heatmap_encoder_train_letters_rand_slots, N=10000, p=0.0005, samples=2000, bit_acc=0.9982, exact_acc=0.8810, scene_exact_acc=0.8810, scene_tol_acc=0.9080, n_eval=2000
# Saved memory checkpoint: ./td_heatmap_encoder_results_randomslots/centerCNN_exp3_TD_heatmap_encoder_train_letters_rand_slots_npost10000_p0.0005_thr7_seed13000.npz
# centerCNN_exp3_TD_heatmap_encoder_train_letters_rand_slots, N=10000, p=0.0005, samples=5000, bit_acc=0.9935, exact_acc=0.6150, scene_exact_acc=0.6150, scene_tol_acc=0.6394, n_eval=5000
# Saved memory checkpoint: ./td_heatmap_encoder_results_randomslots/centerCNN_exp3_TD_heatmap_encoder_train_letters_rand_slots_npost10000_p0.0005_thr7_seed13000.npz
# centerCNN_exp3_TD_heatmap_encoder_train_letters_rand_slots, N=10000, p=0.0005, samples=10000, bit_acc=0.9841, exact_acc=0.1552, scene_exact_acc=0.1552, scene_tol_acc=0.1704, n_eval=10000
# Saved memory checkpoint: ./td_heatmap_encoder_results_randomslots/centerCNN_exp3_TD_heatmap_encoder_train_letters_rand_slots_npost10000_p0.0005_thr7_seed13000.npz
# centerCNN_exp3_TD_heatmap_encoder_train_letters_rand_slots, N=10000, p=0.0005, samples=20000, bit_acc=0.9782, exact_acc=0.0007, scene_exact_acc=0.0007, scene_tol_acc=0.0013, n_eval=10000
# Saved memory checkpoint: ./td_heatmap_encoder_results_randomslots/centerCNN_exp3_TD_heatmap_encoder_train_letters_rand_slots_npost10000_p0.0005_thr7_seed13000.npz
# centerCNN_exp3_TD_heatmap_encoder_train_letters_rand_slots, N=10000, p=0.0005, samples=50000, bit_acc=0.9801, exact_acc=0.0000, scene_exact_acc=0.0000, scene_tol_acc=0.0000, n_eval=10000
# Saved memory checkpoint: ./td_heatmap_encoder_results_randomslots/centerCNN_exp3_TD_heatmap_encoder_train_letters_rand_slots_npost10000_p0.0005_thr7_seed13000.npz
# centerCNN_exp3_TD_heatmap_encoder_train_letters_rand_slots, N=10000, p=0.0005, samples=100000, bit_acc=0.9799, exact_acc=0.0000, scene_exact_acc=0.0000, scene_tol_acc=0.0000, n_eval=10000
# Saved memory checkpoint: ./td_heatmap_encoder_results_randomslots/centerCNN_exp3_TD_heatmap_encoder_train_letters_rand_slots_npost10000_p0.0005_thr7_seed13000.npz
# centerCNN_exp3_TD_heatmap_encoder_train_letters_rand_slots, N=10000, p=0.0005, samples=200000, bit_acc=0.9725, exact_acc=0.0000, scene_exact_acc=0.0000, scene_tol_acc=0.0000, n_eval=10000
# Saved memory checkpoint: ./td_heatmap_encoder_results_randomslots/centerCNN_exp3_TD_heatmap_encoder_train_letters_rand_slots_npost10000_p0.0005_thr7_seed13000.npz
# centerCNN_exp3_TD_heatmap_encoder_train_letters_rand_slots, N=10000, p=0.0005, samples=500000, bit_acc=0.9677, exact_acc=0.0000, scene_exact_acc=0.0000, scene_tol_acc=0.0000, n_eval=10000
# Saved memory checkpoint: ./td_heatmap_encoder_results_randomslots/centerCNN_exp3_TD_heatmap_encoder_train_letters_rand_slots_npost10000_p0.0005_thr7_seed13000.npz
# Saved final memory results: ./td_heatmap_encoder_results_randomslots/centerCNN_exp3_TD_heatmap_encoder_train_letters_rand_slots_npost10000_p0.0005_thr7_seed13000_final.npy
# Starting new memory run: ./td_heatmap_encoder_results_randomslots/centerCNN_exp3_TD_heatmap_encoder_train_letters_rand_slots_npost50000_p0.0002_thr7_seed53000.npz
# training centerCNN_exp3_TD_heatmap_encoder_train_letters_rand_slots, N=50000, p=0.0002:   0%|          | 0/500…
# centerCNN_exp3_TD_heatmap_encoder_train_letters_rand_slots, N=50000, p=0.0002, samples=1, bit_acc=1.0000, exact_acc=1.0000, scene_exact_acc=1.0000, scene_tol_acc=1.0000, n_eval=1
# Saved memory checkpoint: ./td_heatmap_encoder_results_randomslots/centerCNN_exp3_TD_heatmap_encoder_train_letters_rand_slots_npost50000_p0.0002_thr7_seed53000.npz
# centerCNN_exp3_TD_heatmap_encoder_train_letters_rand_slots, N=50000, p=0.0002, samples=10, bit_acc=1.0000, exact_acc=1.0000, scene_exact_acc=1.0000, scene_tol_acc=1.0000, n_eval=10
# Saved memory checkpoint: ./td_heatmap_encoder_results_randomslots/centerCNN_exp3_TD_heatmap_encoder_train_letters_rand_slots_npost50000_p0.0002_thr7_seed53000.npz
# centerCNN_exp3_TD_heatmap_encoder_train_letters_rand_slots, N=50000, p=0.0002, samples=100, bit_acc=0.9999, exact_acc=0.9700, scene_exact_acc=0.9700, scene_tol_acc=1.0000, n_eval=100
# Saved memory checkpoint: ./td_heatmap_encoder_results_randomslots/centerCNN_exp3_TD_heatmap_encoder_train_letters_rand_slots_npost50000_p0.0002_thr7_seed53000.npz
# centerCNN_exp3_TD_heatmap_encoder_train_letters_rand_slots, N=50000, p=0.0002, samples=1000, bit_acc=0.9998, exact_acc=0.9590, scene_exact_acc=0.9590, scene_tol_acc=0.9910, n_eval=1000
# Saved memory checkpoint: ./td_heatmap_encoder_results_randomslots/centerCNN_exp3_TD_heatmap_encoder_train_letters_rand_slots_npost50000_p0.0002_thr7_seed53000.npz
# centerCNN_exp3_TD_heatmap_encoder_train_letters_rand_slots, N=50000, p=0.0002, samples=2000, bit_acc=0.9998, exact_acc=0.9620, scene_exact_acc=0.9620, scene_tol_acc=0.9905, n_eval=2000
# Saved memory checkpoint: ./td_heatmap_encoder_results_randomslots/centerCNN_exp3_TD_heatmap_encoder_train_letters_rand_slots_npost50000_p0.0002_thr7_seed53000.npz
# centerCNN_exp3_TD_heatmap_encoder_train_letters_rand_slots, N=50000, p=0.0002, samples=5000, bit_acc=0.9998, exact_acc=0.9616, scene_exact_acc=0.9616, scene_tol_acc=0.9866, n_eval=5000
# Saved memory checkpoint: ./td_heatmap_encoder_results_randomslots/centerCNN_exp3_TD_heatmap_encoder_train_letters_rand_slots_npost50000_p0.0002_thr7_seed53000.npz
# centerCNN_exp3_TD_heatmap_encoder_train_letters_rand_slots, N=50000, p=0.0002, samples=10000, bit_acc=0.9994, exact_acc=0.9260, scene_exact_acc=0.9260, scene_tol_acc=0.9515, n_eval=10000
# Saved memory checkpoint: ./td_heatmap_encoder_results_randomslots/centerCNN_exp3_TD_heatmap_encoder_train_letters_rand_slots_npost50000_p0.0002_thr7_seed53000.npz
# centerCNN_exp3_TD_heatmap_encoder_train_letters_rand_slots, N=50000, p=0.0002, samples=20000, bit_acc=0.9966, exact_acc=0.6029, scene_exact_acc=0.6029, scene_tol_acc=0.6274, n_eval=10000
# Saved memory checkpoint: ./td_heatmap_encoder_results_randomslots/centerCNN_exp3_TD_heatmap_encoder_train_letters_rand_slots_npost50000_p0.0002_thr7_seed53000.npz
# centerCNN_exp3_TD_heatmap_encoder_train_letters_rand_slots, N=50000, p=0.0002, samples=50000, bit_acc=0.9857, exact_acc=0.0004, scene_exact_acc=0.0004, scene_tol_acc=0.0008, n_eval=10000
# Saved memory checkpoint: ./td_heatmap_encoder_results_randomslots/centerCNN_exp3_TD_heatmap_encoder_train_letters_rand_slots_npost50000_p0.0002_thr7_seed53000.npz
# centerCNN_exp3_TD_heatmap_encoder_train_letters_rand_slots, N=50000, p=0.0002, samples=100000, bit_acc=0.9821, exact_acc=0.0000, scene_exact_acc=0.0000, scene_tol_acc=0.0000, n_eval=10000
# Saved memory checkpoint: ./td_heatmap_encoder_results_randomslots/centerCNN_exp3_TD_heatmap_encoder_train_letters_rand_slots_npost50000_p0.0002_thr7_seed53000.npz
# centerCNN_exp3_TD_heatmap_encoder_train_letters_rand_slots, N=50000, p=0.0002, samples=200000, bit_acc=0.9802, exact_acc=0.0000, scene_exact_acc=0.0000, scene_tol_acc=0.0000, n_eval=10000
# Saved memory checkpoint: ./td_heatmap_encoder_results_randomslots/centerCNN_exp3_TD_heatmap_encoder_train_letters_rand_slots_npost50000_p0.0002_thr7_seed53000.npz
# centerCNN_exp3_TD_heatmap_encoder_train_letters_rand_slots, N=50000, p=0.0002, samples=500000, bit_acc=0.9800, exact_acc=0.0000, scene_exact_acc=0.0000, scene_tol_acc=0.0000, n_eval=10000
# Saved memory checkpoint: ./td_heatmap_encoder_results_randomslots/centerCNN_exp3_TD_heatmap_encoder_train_letters_rand_slots_npost50000_p0.0002_thr7_seed53000.npz
# Saved final memory results: ./td_heatmap_encoder_results_randomslots/centerCNN_exp3_TD_heatmap_encoder_train_letters_rand_slots_npost50000_p0.0002_thr7_seed53000_final.npy
#
# ========== Exp 3 TD: test letters only, randomized slots ==========
# Starting new memory run: ./td_heatmap_encoder_results_randomslots/centerCNN_exp3_TD_heatmap_encoder_test_letters_rand_slots_npost10000_p0.0005_thr7_seed14000.npz
# training centerCNN_exp3_TD_heatmap_encoder_test_letters_rand_slots, N=10000, p=0.0005:   0%|          | 0/5000…
# centerCNN_exp3_TD_heatmap_encoder_test_letters_rand_slots, N=10000, p=0.0005, samples=1, bit_acc=1.0000, exact_acc=1.0000, scene_exact_acc=1.0000, scene_tol_acc=1.0000, n_eval=1
# Saved memory checkpoint: ./td_heatmap_encoder_results_randomslots/centerCNN_exp3_TD_heatmap_encoder_test_letters_rand_slots_npost10000_p0.0005_thr7_seed14000.npz
# centerCNN_exp3_TD_heatmap_encoder_test_letters_rand_slots, N=10000, p=0.0005, samples=10, bit_acc=0.9974, exact_acc=0.7000, scene_exact_acc=0.7000, scene_tol_acc=0.8000, n_eval=10
# Saved memory checkpoint: ./td_heatmap_encoder_results_randomslots/centerCNN_exp3_TD_heatmap_encoder_test_letters_rand_slots_npost10000_p0.0005_thr7_seed14000.npz
# centerCNN_exp3_TD_heatmap_encoder_test_letters_rand_slots, N=10000, p=0.0005, samples=100, bit_acc=0.9981, exact_acc=0.7400, scene_exact_acc=0.7400, scene_tol_acc=0.8200, n_eval=100
# Saved memory checkpoint: ./td_heatmap_encoder_results_randomslots/centerCNN_exp3_TD_heatmap_encoder_test_letters_rand_slots_npost10000_p0.0005_thr7_seed14000.npz
# centerCNN_exp3_TD_heatmap_encoder_test_letters_rand_slots, N=10000, p=0.0005, samples=1000, bit_acc=0.9980, exact_acc=0.7490, scene_exact_acc=0.7490, scene_tol_acc=0.8070, n_eval=1000
# Saved memory checkpoint: ./td_heatmap_encoder_results_randomslots/centerCNN_exp3_TD_heatmap_encoder_test_letters_rand_slots_npost10000_p0.0005_thr7_seed14000.npz
# centerCNN_exp3_TD_heatmap_encoder_test_letters_rand_slots, N=10000, p=0.0005, samples=2000, bit_acc=0.9971, exact_acc=0.7090, scene_exact_acc=0.7090, scene_tol_acc=0.7705, n_eval=2000
# Saved memory checkpoint: ./td_heatmap_encoder_results_randomslots/centerCNN_exp3_TD_heatmap_encoder_test_letters_rand_slots_npost10000_p0.0005_thr7_seed14000.npz
# centerCNN_exp3_TD_heatmap_encoder_test_letters_rand_slots, N=10000, p=0.0005, samples=5000, bit_acc=0.9927, exact_acc=0.4870, scene_exact_acc=0.4870, scene_tol_acc=0.5392, n_eval=5000
# Saved memory checkpoint: ./td_heatmap_encoder_results_randomslots/centerCNN_exp3_TD_heatmap_encoder_test_letters_rand_slots_npost10000_p0.0005_thr7_seed14000.npz
# centerCNN_exp3_TD_heatmap_encoder_test_letters_rand_slots, N=10000, p=0.0005, samples=10000, bit_acc=0.9837, exact_acc=0.1243, scene_exact_acc=0.1243, scene_tol_acc=0.1461, n_eval=10000
# Saved memory checkpoint: ./td_heatmap_encoder_results_randomslots/centerCNN_exp3_TD_heatmap_encoder_test_letters_rand_slots_npost10000_p0.0005_thr7_seed14000.npz
# centerCNN_exp3_TD_heatmap_encoder_test_letters_rand_slots, N=10000, p=0.0005, samples=20000, bit_acc=0.9779, exact_acc=0.0005, scene_exact_acc=0.0005, scene_tol_acc=0.0012, n_eval=10000
# Saved memory checkpoint: ./td_heatmap_encoder_results_randomslots/centerCNN_exp3_TD_heatmap_encoder_test_letters_rand_slots_npost10000_p0.0005_thr7_seed14000.npz
# centerCNN_exp3_TD_heatmap_encoder_test_letters_rand_slots, N=10000, p=0.0005, samples=50000, bit_acc=0.9793, exact_acc=0.0000, scene_exact_acc=0.0000, scene_tol_acc=0.0000, n_eval=10000
# Saved memory checkpoint: ./td_heatmap_encoder_results_randomslots/centerCNN_exp3_TD_heatmap_encoder_test_letters_rand_slots_npost10000_p0.0005_thr7_seed14000.npz
# centerCNN_exp3_TD_heatmap_encoder_test_letters_rand_slots, N=10000, p=0.0005, samples=100000, bit_acc=0.9792, exact_acc=0.0000, scene_exact_acc=0.0000, scene_tol_acc=0.0000, n_eval=10000
# Saved memory checkpoint: ./td_heatmap_encoder_results_randomslots/centerCNN_exp3_TD_heatmap_encoder_test_letters_rand_slots_npost10000_p0.0005_thr7_seed14000.npz
# centerCNN_exp3_TD_heatmap_encoder_test_letters_rand_slots, N=10000, p=0.0005, samples=200000, bit_acc=0.9724, exact_acc=0.0000, scene_exact_acc=0.0000, scene_tol_acc=0.0000, n_eval=10000
# Saved memory checkpoint: ./td_heatmap_encoder_results_randomslots/centerCNN_exp3_TD_heatmap_encoder_test_letters_rand_slots_npost10000_p0.0005_thr7_seed14000.npz
# centerCNN_exp3_TD_heatmap_encoder_test_letters_rand_slots, N=10000, p=0.0005, samples=500000, bit_acc=0.9677, exact_acc=0.0000, scene_exact_acc=0.0000, scene_tol_acc=0.0000, n_eval=10000
# Saved memory checkpoint: ./td_heatmap_encoder_results_randomslots/centerCNN_exp3_TD_heatmap_encoder_test_letters_rand_slots_npost10000_p0.0005_thr7_seed14000.npz
# Saved final memory results: ./td_heatmap_encoder_results_randomslots/centerCNN_exp3_TD_heatmap_encoder_test_letters_rand_slots_npost10000_p0.0005_thr7_seed14000_final.npy
# Starting new memory run: ./td_heatmap_encoder_results_randomslots/centerCNN_exp3_TD_heatmap_encoder_test_letters_rand_slots_npost50000_p0.0002_thr7_seed54000.npz
# training centerCNN_exp3_TD_heatmap_encoder_test_letters_rand_slots, N=50000, p=0.0002:   0%|          | 0/5000…
# centerCNN_exp3_TD_heatmap_encoder_test_letters_rand_slots, N=50000, p=0.0002, samples=1, bit_acc=1.0000, exact_acc=1.0000, scene_exact_acc=1.0000, scene_tol_acc=1.0000, n_eval=1
# Saved memory checkpoint: ./td_heatmap_encoder_results_randomslots/centerCNN_exp3_TD_heatmap_encoder_test_letters_rand_slots_npost50000_p0.0002_thr7_seed54000.npz
# centerCNN_exp3_TD_heatmap_encoder_test_letters_rand_slots, N=50000, p=0.0002, samples=10, bit_acc=0.9974, exact_acc=0.7000, scene_exact_acc=0.7000, scene_tol_acc=0.8000, n_eval=10
# Saved memory checkpoint: ./td_heatmap_encoder_results_randomslots/centerCNN_exp3_TD_heatmap_encoder_test_letters_rand_slots_npost50000_p0.0002_thr7_seed54000.npz
# centerCNN_exp3_TD_heatmap_encoder_test_letters_rand_slots, N=50000, p=0.0002, samples=100, bit_acc=0.9985, exact_acc=0.7500, scene_exact_acc=0.7500, scene_tol_acc=0.8300, n_eval=100
# Saved memory checkpoint: ./td_heatmap_encoder_results_randomslots/centerCNN_exp3_TD_heatmap_encoder_test_letters_rand_slots_npost50000_p0.0002_thr7_seed54000.npz
# centerCNN_exp3_TD_heatmap_encoder_test_letters_rand_slots, N=50000, p=0.0002, samples=1000, bit_acc=0.9988, exact_acc=0.7750, scene_exact_acc=0.7750, scene_tol_acc=0.8350, n_eval=1000
# Saved memory checkpoint: ./td_heatmap_encoder_results_randomslots/centerCNN_exp3_TD_heatmap_encoder_test_letters_rand_slots_npost50000_p0.0002_thr7_seed54000.npz
# centerCNN_exp3_TD_heatmap_encoder_test_letters_rand_slots, N=50000, p=0.0002, samples=2000, bit_acc=0.9988, exact_acc=0.7745, scene_exact_acc=0.7745, scene_tol_acc=0.8405, n_eval=2000
# Saved memory checkpoint: ./td_heatmap_encoder_results_randomslots/centerCNN_exp3_TD_heatmap_encoder_test_letters_rand_slots_npost50000_p0.0002_thr7_seed54000.npz
# centerCNN_exp3_TD_heatmap_encoder_test_letters_rand_slots, N=50000, p=0.0002, samples=5000, bit_acc=0.9987, exact_acc=0.7738, scene_exact_acc=0.7738, scene_tol_acc=0.8432, n_eval=5000
# Saved memory checkpoint: ./td_heatmap_encoder_results_randomslots/centerCNN_exp3_TD_heatmap_encoder_test_letters_rand_slots_npost50000_p0.0002_thr7_seed54000.npz
# centerCNN_exp3_TD_heatmap_encoder_test_letters_rand_slots, N=50000, p=0.0002, samples=10000, bit_acc=0.9984, exact_acc=0.7453, scene_exact_acc=0.7453, scene_tol_acc=0.8098, n_eval=10000
# Saved memory checkpoint: ./td_heatmap_encoder_results_randomslots/centerCNN_exp3_TD_heatmap_encoder_test_letters_rand_slots_npost50000_p0.0002_thr7_seed54000.npz
# centerCNN_exp3_TD_heatmap_encoder_test_letters_rand_slots, N=50000, p=0.0002, samples=20000, bit_acc=0.9957, exact_acc=0.4702, scene_exact_acc=0.4702, scene_tol_acc=0.5209, n_eval=10000
# Saved memory checkpoint: ./td_heatmap_encoder_results_randomslots/centerCNN_exp3_TD_heatmap_encoder_test_letters_rand_slots_npost50000_p0.0002_thr7_seed54000.npz
# centerCNN_exp3_TD_heatmap_encoder_test_letters_rand_slots, N=50000, p=0.0002, samples=50000, bit_acc=0.9848, exact_acc=0.0006, scene_exact_acc=0.0006, scene_tol_acc=0.0011, n_eval=10000
# Saved memory checkpoint: ./td_heatmap_encoder_results_randomslots/centerCNN_exp3_TD_heatmap_encoder_test_letters_rand_slots_npost50000_p0.0002_thr7_seed54000.npz
# centerCNN_exp3_TD_heatmap_encoder_test_letters_rand_slots, N=50000, p=0.0002, samples=100000, bit_acc=0.9813, exact_acc=0.0000, scene_exact_acc=0.0000, scene_tol_acc=0.0001, n_eval=10000
# Saved memory checkpoint: ./td_heatmap_encoder_results_randomslots/centerCNN_exp3_TD_heatmap_encoder_test_letters_rand_slots_npost50000_p0.0002_thr7_seed54000.npz
# centerCNN_exp3_TD_heatmap_encoder_test_letters_rand_slots, N=50000, p=0.0002, samples=200000, bit_acc=0.9795, exact_acc=0.0000, scene_exact_acc=0.0000, scene_tol_acc=0.0000, n_eval=10000
# Saved memory checkpoint: ./td_heatmap_encoder_results_randomslots/centerCNN_exp3_TD_heatmap_encoder_test_letters_rand_slots_npost50000_p0.0002_thr7_seed54000.npz
# centerCNN_exp3_TD_heatmap_encoder_test_letters_rand_slots, N=50000, p=0.0002, samples=500000, bit_acc=0.9793, exact_acc=0.0000, scene_exact_acc=0.0000, scene_tol_acc=0.0000, n_eval=10000
# Saved memory checkpoint: ./td_heatmap_encoder_results_randomslots/centerCNN_exp3_TD_heatmap_encoder_test_letters_rand_slots_npost50000_p0.0002_thr7_seed54000.npz
# Saved final memory results: ./td_heatmap_encoder_results_randomslots/centerCNN_exp3_TD_heatmap_encoder_test_letters_rand_slots_npost50000_p0.0002_thr7_seed54000_final.npy
# Saved all results: ./td_heatmap_encoder_results_randomslots/all_exp3_td_heatmap_encoder_results_rand_slots.npy
# ========== Summary ==========
#
#  train_exp3_10000_0.0005
# x_range         : [     1     10    100   1000   2000   5000  10000  20000  50000 100000
#  200000 500000]
# scene_exact_acc : [1.000e+00 1.000e+00 9.700e-01 9.270e-01 8.810e-01 6.150e-01 1.552e-01
#  7.000e-04 0.000e+00 0.000e+00 0.000e+00 0.000e+00]
# exact_acc       : [1.000e+00 1.000e+00 9.700e-01 9.270e-01 8.810e-01 6.150e-01 1.552e-01
#  7.000e-04 0.000e+00 0.000e+00 0.000e+00 0.000e+00]
# bit_acc         : [1.     1.     0.9999 0.9991 0.9982 0.9935 0.9841 0.9782 0.9801 0.9799
#  0.9725 0.9677]
# n_eval          : [    1    10   100  1000  2000  5000 10000 10000 10000 10000 10000 10000]
#
#  train_exp3_50000_0.0002
# x_range         : [     1     10    100   1000   2000   5000  10000  20000  50000 100000
#  200000 500000]
# scene_exact_acc : [1.000e+00 1.000e+00 9.700e-01 9.590e-01 9.620e-01 9.616e-01 9.260e-01
#  6.029e-01 4.000e-04 0.000e+00 0.000e+00 0.000e+00]
# exact_acc       : [1.000e+00 1.000e+00 9.700e-01 9.590e-01 9.620e-01 9.616e-01 9.260e-01
#  6.029e-01 4.000e-04 0.000e+00 0.000e+00 0.000e+00]
# bit_acc         : [1.     1.     0.9999 0.9998 0.9998 0.9998 0.9994 0.9966 0.9857 0.9821
#  0.9802 0.98  ]
# n_eval          : [    1    10   100  1000  2000  5000 10000 10000 10000 10000 10000 10000]
#
#  test_exp3_10000_0.0005
# x_range         : [     1     10    100   1000   2000   5000  10000  20000  50000 100000
#  200000 500000]
# scene_exact_acc : [1.000e+00 7.000e-01 7.400e-01 7.490e-01 7.090e-01 4.870e-01 1.243e-01
#  5.000e-04 0.000e+00 0.000e+00 0.000e+00 0.000e+00]
# exact_acc       : [1.000e+00 7.000e-01 7.400e-01 7.490e-01 7.090e-01 4.870e-01 1.243e-01
#  5.000e-04 0.000e+00 0.000e+00 0.000e+00 0.000e+00]
# bit_acc         : [1.     0.9974 0.9981 0.998  0.9971 0.9927 0.9837 0.9779 0.9793 0.9792
#  0.9724 0.9677]
# n_eval          : [    1    10   100  1000  2000  5000 10000 10000 10000 10000 10000 10000]
#
#  test_exp3_50000_0.0002
# x_range         : [     1     10    100   1000   2000   5000  10000  20000  50000 100000
#  200000 500000]
# scene_exact_acc : [1.000e+00 7.000e-01 7.500e-01 7.750e-01 7.745e-01 7.738e-01 7.453e-01
#  4.702e-01 6.000e-04 0.000e+00 0.000e+00 0.000e+00]
# exact_acc       : [1.000e+00 7.000e-01 7.500e-01 7.750e-01 7.745e-01 7.738e-01 7.453e-01
#  4.702e-01 6.000e-04 0.000e+00 0.000e+00 0.000e+00]
# bit_acc         : [1.     0.9974 0.9985 0.9988 0.9988 0.9987 0.9984 0.9957 0.9848 0.9813
#  0.9795 0.9793]
# n_eval          : [    1    10   100  1000  2000  5000 10000 10000 10000 10000 10000 10000]

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
TD_CACHE_DIR = "./td_heatmap_encoder_results_randomslots"

all_results_path = os.path.join(
    TD_CACHE_DIR,
    "all_exp3_td_heatmap_encoder_results_rand_slots.npy"
)

all_results = np.load(all_results_path, allow_pickle=True).item()

print(all_results.keys())

def plot_td_pair(res_10000, res_50000, title=None, xlim=(10, 600000), ylim=(0, 103.5)):
    
    plt.figure(figsize=(4*0.8,3*0.8),dpi=300)
    plt.plot(
        res_50000["x_range"][1:],
        np.cbrt(res_50000["scene_tolerant_exact_acc"])[1:] * 100,
        marker="o",
        lw=3,
        label="N=5e4, fq=0.02%",
        color="tab:blue",
        alpha=0.85,
    )

    plt.plot(
        res_10000["x_range"][1:],
        np.cbrt(res_10000["scene_tolerant_exact_acc"])[1:] * 100,
        marker="o",
        lw=3,
        label="N=1e4, fq=0.05%",
        color="tab:orange",
        alpha=0.85,
    )


    plt.xscale("log")
    plt.xlim(*xlim)
    plt.ylim(*ylim)

    plt.xlabel("Number of stored canvases")
    plt.ylabel("TD unbinding accuracy / %")
    plt.title(title)
    plt.legend()
    plt.tight_layout()
    plt.show()

    
plot_td_pair(
    res_10000=all_results["train_exp3_10000_0.0005"],
    res_50000=all_results["train_exp3_50000_0.0002"],
#     title="Exp 3 TD: heatmap encoder, train letters, randomized slots",
    xlim=(10, 100000),
    ylim=(0, 103.5),
)

plot_td_pair(
    res_10000=all_results["test_exp3_10000_0.0005"],
    res_50000=all_results["test_exp3_50000_0.0002"],
#     title="Exp 3 TD: heatmap encoder, test letters, randomized slots",
    xlim=(10, 100000),
    ylim=(0, 103.5),
)
# Out:
# dict_keys(['train_exp3_10000_0.0005', 'train_exp3_50000_0.0002', 'test_exp3_10000_0.0005', 'test_exp3_50000_0.0002'])
